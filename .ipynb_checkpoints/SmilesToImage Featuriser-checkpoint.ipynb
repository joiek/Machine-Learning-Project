# %%
#Import Statements
import deepchem as dc
from rdkit import Chem
from rdkit.Chem import Draw
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras import layers, losses

import pandas as pd

from matplotlib import pyplot as plt

import numpy as np

from sklearn import metrics
from sklearn.metrics import f1_score
from sklearn.metrics import (precision_recall_curve, average_precision_score, PrecisionRecallDisplay)
from sklearn.metrics import accuracy_score

import keras
from keras import layers

# %% [markdown]
# ### Loading Tox21 dataset using SmilesToImage featuriser

# %% [markdown]
# Tox21 Assay List: <br>
# <ol>
#     <li> NR-AR </li>
#     <li> NR-AR-LBD </li>
#     <li> NR-AhR </li>
#     <li> NR-Aromatase </li>
#     <li> NR-ER </li>
#     <li> NR-ER-LBD </li>
#     <li> NR-PPAR-gamma </li>
#     <li> SR-ARE </li>
#     <li> SR-ATAD5 </li>
#     <li> SR-HSE </li>
#     <li> SR-MMP </li>
#     <li> SR-p53 </li>
# </ol>

# %%
# dc.__version__

# %%
#Testing NN with SmilesToImage featuriser
tasks, datasets, transformers = dc.molnet.load_tox21(
    featurizer = dc.feat.SmilesToImage(img_size=80, img_spec='std'),
    save_dir=r'C:\Users\ym20201\Documents\Datasets',
    data_dir=r'C:\Users\ym20201\Documents\Datasets')

splitter = dc.splits.RandomSplitter()
# featurizer = dc.feat.SmilesToImage(img_size=80, img_spec='std')

# datasets = tf.data.Dataset.range(3)

#Split dataset into train,valid,test datasets
# train_data, valid_data,test_data = splitter.train_valid_test_split(
#     datasets[0], 
#     frac_train = 0.8, frac_valid = 0.08, frac_test = 0.12)

train_data, valid_data, test_data = datasets

# %% [markdown]
# ### DeepChem CNN model

# %%
#Model 1
smiles2img_model = dc.models.CNN(
    n_tasks = len(tasks), # Num of tasks, i.e. width of y
    n_features=len(train_data.X[2]), # number of features, i.e. width of X
    dims=1,
    mode='classification',
    weight_init_stddevs=0.02, 
    bias_init_consts=1.0,
    dropouts=[0.5, 0.0],
    activation_fns=['relu', 'relu'],
    learning_rate=0.01,
    batch_size=100)

# %%
#Model 2 with max pooling layer 
smiles2img_model = dc.models.CNN(
    n_tasks = len(tasks), # Num of tasks, i.e. width of y
    n_features=len(train_data.X[2]), # number of features, i.e. width of X
    dims=1,
    mode='classification',
    weight_init_stddevs=0.02, 
    bias_init_consts=1.0,
    dropouts=[0.5, 0.0],
    pool_type='max',
    activation_fns=['relu', 'relu'],
    learning_rate=0.01,
    batch_size=100)

# %%
#Model 3
smiles2img_model = dc.models.CNN(
    n_tasks = len(tasks), # Num of tasks, i.e. width of y
    n_features=len(train_data.X[2]), # number of features, i.e. width of X
    dims=1,
    layer_filter=[1000,500,10], 
    mode='classification',
    weight_init_stddevs=0.02, 
    bias_init_consts=1.0,
    dropouts=[0.8, 0.5,0.0],
    activation_fns=['relu', 'relu', 'relu'],
    learning_rate=0.01,
    batch_size=100)

# %%
#Model 4
smiles2img_model = dc.models.CNN(
    n_tasks = len(tasks), # Num of tasks, i.e. width of y
    n_features=len(train_data.X[2]), # number of features, i.e. width of X
    dims=1,
    layer_filter=[500,500,200],
    mode='classification',
    weight_init_stddevs=0.02, 
    bias_init_consts=1.0,
    dropouts=[0.5, 0.0,0.0],
    #dropouts=[0.8, 0.5,0.0],
    activation_fns=['relu', 'relu', 'relu'],
    learning_rate=0.01,
    batch_size=100)

# %%
#Parameters of CNN model
#dims= 1,2,or 3 (no. of dimensions to apply convolutions over)
#layer_filter=list (length of list determines no. of layers)
#dropouts=list or float (dropout probability for each layer - len(list) = len(layer_filter)
#pool_type='max' or 'average' (type of pooling layer to use)
#padding='valid' or 'same' (padding to use for conv layers) default valid(no padding)

# %%
smiles2img_model.fit(
    train_data,
    nb_epoch=10)
# Out:
# 1.0845901489257812

# %%
#Using the model for prediction
pred_data = smiles2img_model.predict(test_data)

# %%
#Function for accessing y_true of each assay
def y_true(assay_num, test_data):
    y_true = []
    for i in range(len(test_data.y)):
        y_true.append(test_data.y[i][assay_num - 1])
        
    return y_true

def y_pred(assay_num, pred_data):
    y_pred = []
    for i in range(len(pred_data)):
        y_pred.append( pred_data[i][assay_num - 1][0])
#         y_pred = pred_data[i][assay_num - 1] #not sure which one
    
    return y_pred

# %%
# pred_data

# %% [markdown]
# why does pred_data[i][assay_num - 1] give two numbers? [print cell below]

# %%
test = [pred_data[i][3] for i in range(len(pred_data))]
test
# Out:
# [array([0.49679807, 0.50320196], dtype=float32),
#  array([0.44773072, 0.55226934], dtype=float32),
#  array([0.37208945, 0.6279105 ], dtype=float32),
#  array([0.4177292, 0.5822708], dtype=float32),
#  array([0.15665025, 0.84334975], dtype=float32),
#  array([0.481279  , 0.51872104], dtype=float32),
#  array([0.3549384, 0.6450616], dtype=float32),
#  array([0.4487762, 0.5512238], dtype=float32),
#  array([0.3396108 , 0.66038924], dtype=float32),
#  array([0.59259963, 0.4074004 ], dtype=float32),
#  array([0.3225041, 0.6774959], dtype=float32),
#  array([0.51031446, 0.4896856 ], dtype=float32),
#  array([0.5158468 , 0.48415324], dtype=float32),
#  array([0.7968285, 0.2031715], dtype=float32),
#  array([0.5516662 , 0.44833374], dtype=float32),
#  array([0.45495462, 0.54504544], dtype=float32),
#  array([0.45943114, 0.5405688 ], dtype=float32),
#  array([0.31824842, 0.68175155], dtype=float32),
#  array([0.40700942, 0.5929906 ], dtype=float32),
#  array([0.4221701 , 0.57782996], dtype=float32),
#  array([0.46545285, 0.53454715], dtype=float32),
#  array([0.170416, 0.829584], dtype=float32),
#  array([0.32102212, 0.67897785], dtype=float32),
#  array([0.7462275 , 0.25377253], dtype=float32),
#  array([0.50068885, 0.49931115], dtype=float32),
#  array([0.2944002, 0.7055998], dtype=float32),
#  array([0.5759083 , 0.42409164], dtype=float32),
#  array([0.26614434, 0.73385566], dtype=float32),
#  array([0.20246737, 0.7975327 ], dtype=float32),
#  array([0.57282525, 0.42717472], dtype=float32),
#  array([0.98198986, 0.01801012], dtype=float32),
#  array([0.44121385, 0.5587862 ], dtype=float32),
#  array([0.68642175, 0.31357825], dtype=float32),
#  array([0.27666262, 0.7233373 ], dtype=float32),
#  array([0.3722229 , 0.62777716], dtype=float32),
#  array([0.45570093, 0.544299  ], dtype=float32),
#  array([0.42283517, 0.5771648 ], dtype=float32),
#  array([0.42463994, 0.5753601 ], dtype=float32),
#  array([0.48861513, 0.5113849 ], dtype=float32),
#  array([0.44602555, 0.5539744 ], dtype=float32),
#  array([0.46618062, 0.5338193 ], dtype=float32),
#  array([0.26708966, 0.73291034], dtype=float32),
#  array([0.22056052, 0.77943945], dtype=float32),
#  array([0.1957829 , 0.80421704], dtype=float32),
#  array([0.38704702, 0.61295295], dtype=float32),
#  array([0.2524055, 0.7475945], dtype=float32),
#  array([0.577657  , 0.42234302], dtype=float32),
#  array([0.98871815, 0.01128187], dtype=float32),
#  array([0.4615351, 0.5384649], dtype=float32),
#  array([0.50565565, 0.49434438], dtype=float32),
#  array([0.26957905, 0.7304209 ], dtype=float32),
#  array([0.43304533, 0.5669547 ], dtype=float32),
#  array([0.7936428 , 0.20635714], dtype=float32),
#  array([0.3350533, 0.6649467], dtype=float32),
#  array([0.45276296, 0.5472371 ], dtype=float32),
#  array([0.36564085, 0.6343591 ], dtype=float32),
#  array([0.3272442, 0.6727558], dtype=float32),
#  array([0.4657933, 0.5342067], dtype=float32),
#  array([0.2485024, 0.7514976], dtype=float32),
#  array([0.9242365 , 0.07576348], dtype=float32),
#  array([0.48615074, 0.51384926], dtype=float32),
#  array([0.75182503, 0.24817502], dtype=float32),
#  array([0.3324455 , 0.66755444], dtype=float32),
#  array([0.3713097 , 0.62869024], dtype=float32),
#  array([0.39937276, 0.6006272 ], dtype=float32),
#  array([0.4009985, 0.5990015], dtype=float32),
#  array([0.54883385, 0.45116618], dtype=float32),
#  array([0.29889438, 0.7011056 ], dtype=float32),
#  array([0.51488435, 0.48511565], dtype=float32),
#  array([0.26450452, 0.7354955 ], dtype=float32),
#  array([0.3275936 , 0.67240644], dtype=float32),
#  array([0.42048314, 0.5795169 ], dtype=float32),
#  array([0.40657312, 0.5934269 ], dtype=float32),
#  array([0.46476457, 0.53523546], dtype=float32),
#  array([0.47016966, 0.52983034], dtype=float32),
#  array([0.17344593, 0.82655406], dtype=float32),
#  array([0.8535881 , 0.14641194], dtype=float32),
#  array([0.8835661 , 0.11643393], dtype=float32),
#  array([0.4046533, 0.5953467], dtype=float32),
#  array([0.28814855, 0.7118514 ], dtype=float32),
#  array([0.27645567, 0.72354436], dtype=float32),
#  array([0.4091998, 0.5908001], dtype=float32),
#  array([0.3879654 , 0.61203456], dtype=float32),
#  array([0.78389287, 0.21610712], dtype=float32),
#  array([0.39309782, 0.6069022 ], dtype=float32),
#  array([0.1567237 , 0.84327626], dtype=float32),
#  array([0.50645393, 0.49354613], dtype=float32),
#  array([0.44264138, 0.5573586 ], dtype=float32),
#  array([0.5435989, 0.4564011], dtype=float32),
#  array([0.3731589 , 0.62684107], dtype=float32),
#  array([0.5246808 , 0.47531924], dtype=float32),
#  array([0.6427101 , 0.35728988], dtype=float32),
#  array([0.4863609 , 0.51363903], dtype=float32),
#  array([0.17709059, 0.82290936], dtype=float32),
#  array([0.37354124, 0.62645876], dtype=float32),
#  array([0.42792848, 0.5720715 ], dtype=float32),
#  array([0.3322046, 0.6677954], dtype=float32),
#  array([0.48969123, 0.51030874], dtype=float32),
#  array([0.37385792, 0.6261421 ], dtype=float32),
#  array([0.42610455, 0.57389545], dtype=float32),
#  array([0.4992233, 0.5007767], dtype=float32),
#  array([0.50051516, 0.49948484], dtype=float32),
#  array([0.5350393 , 0.46496072], dtype=float32),
#  array([0.711247  , 0.28875303], dtype=float32),
#  array([0.35574946, 0.64425063], dtype=float32),
#  array([0.4686752, 0.5313248], dtype=float32),
#  array([0.36128092, 0.6387191 ], dtype=float32),
#  array([0.81163627, 0.18836375], dtype=float32),
#  array([0.5057788 , 0.49422118], dtype=float32),
#  array([0.19770826, 0.8022917 ], dtype=float32),
#  array([0.53557575, 0.46442428], dtype=float32),
#  array([0.36239836, 0.6376016 ], dtype=float32),
#  array([0.1918783, 0.8081217], dtype=float32),
#  array([0.33106235, 0.6689377 ], dtype=float32),
#  array([0.39676172, 0.60323834], dtype=float32),
#  array([0.397267, 0.602733], dtype=float32),
#  array([0.5664822 , 0.43351784], dtype=float32),
#  array([0.817821  , 0.18217897], dtype=float32),
#  array([0.07335579, 0.9266442 ], dtype=float32),
#  array([0.5263947 , 0.47360528], dtype=float32),
#  array([0.43786982, 0.56213015], dtype=float32),
#  array([0.36536297, 0.634637  ], dtype=float32),
#  array([0.32323816, 0.67676187], dtype=float32),
#  array([0.30809587, 0.6919041 ], dtype=float32),
#  array([0.4219399, 0.5780601], dtype=float32),
#  array([0.3601664 , 0.63983357], dtype=float32),
#  array([0.62378746, 0.3762125 ], dtype=float32),
#  array([0.4048291 , 0.59517086], dtype=float32),
#  array([0.54916126, 0.4508387 ], dtype=float32),
#  array([0.3395785, 0.6604215], dtype=float32),
#  array([0.4715112, 0.5284888], dtype=float32),
#  array([0.3096186, 0.6903814], dtype=float32),
#  array([0.42905986, 0.5709401 ], dtype=float32),
#  array([0.38357863, 0.6164214 ], dtype=float32),
#  array([0.35476947, 0.6452306 ], dtype=float32),
#  array([0.52172136, 0.47827858], dtype=float32),
#  array([0.35616753, 0.6438325 ], dtype=float32),
#  array([0.9936888 , 0.00631121], dtype=float32),
#  array([0.56197053, 0.43802953], dtype=float32),
#  array([0.46982333, 0.5301766 ], dtype=float32),
#  array([0.43862432, 0.5613756 ], dtype=float32),
#  array([0.09318496, 0.90681505], dtype=float32),
#  array([0.94384176, 0.0561582 ], dtype=float32),
#  array([0.5727138, 0.4272862], dtype=float32),
#  array([0.3417461 , 0.65825397], dtype=float32),
#  array([0.53372896, 0.4662711 ], dtype=float32),
#  array([0.8536368 , 0.14636312], dtype=float32),
#  array([0.47752252, 0.5224775 ], dtype=float32),
#  array([0.4252132 , 0.57478684], dtype=float32),
#  array([0.61015904, 0.38984093], dtype=float32),
#  array([0.15567069, 0.84432924], dtype=float32),
#  array([0.52408797, 0.47591195], dtype=float32),
#  array([0.407038  , 0.59296197], dtype=float32),
#  array([0.58884746, 0.41115257], dtype=float32),
#  array([0.49002138, 0.5099786 ], dtype=float32),
#  array([0.8368432 , 0.16315678], dtype=float32),
#  array([0.3696858, 0.6303143], dtype=float32),
#  array([0.11095705, 0.88904303], dtype=float32),
#  array([0.48729768, 0.5127023 ], dtype=float32),
#  array([0.3892589 , 0.61074114], dtype=float32),
#  array([0.6249876, 0.3750124], dtype=float32),
#  array([0.72492135, 0.27507862], dtype=float32),
#  array([0.77273095, 0.2272691 ], dtype=float32),
#  array([0.39752427, 0.6024757 ], dtype=float32),
#  array([0.3687585 , 0.63124156], dtype=float32),
#  array([0.47260675, 0.5273933 ], dtype=float32),
#  array([0.49811, 0.50189], dtype=float32),
#  array([0.408547, 0.591453], dtype=float32),
#  array([0.20958115, 0.79041886], dtype=float32),
#  array([0.5241068 , 0.47589323], dtype=float32),
#  array([0.6943604 , 0.30563962], dtype=float32),
#  array([0.5911402, 0.4088598], dtype=float32),
#  array([0.787302  , 0.21269797], dtype=float32),
#  array([0.49914485, 0.5008551 ], dtype=float32),
#  array([0.391709  , 0.60829103], dtype=float32),
#  array([0.5413213 , 0.45867875], dtype=float32),
#  array([0.36674586, 0.6332541 ], dtype=float32),
#  array([0.3774399 , 0.62256014], dtype=float32),
#  array([0.57715607, 0.42284393], dtype=float32),
#  array([0.05540402, 0.94459593], dtype=float32),
#  array([0.46202025, 0.5379797 ], dtype=float32),
#  array([0.57496816, 0.4250318 ], dtype=float32),
#  array([0.8955926 , 0.10440741], dtype=float32),
#  array([0.5162183, 0.4837817], dtype=float32),
#  array([0.72985846, 0.27014148], dtype=float32),
#  array([0.40365937, 0.59634066], dtype=float32),
#  array([0.58728796, 0.41271204], dtype=float32),
#  array([0.9986247 , 0.00137533], dtype=float32),
#  array([0.51067156, 0.48932838], dtype=float32),
#  array([0.46116847, 0.53883153], dtype=float32),
#  array([0.4119861 , 0.58801395], dtype=float32),
#  array([0.61767304, 0.38232693], dtype=float32),
#  array([0.78734744, 0.2126526 ], dtype=float32),
#  array([0.3439632, 0.6560368], dtype=float32),
#  array([0.65114367, 0.34885642], dtype=float32),
#  array([0.3612327, 0.6387673], dtype=float32),
#  array([0.38503546, 0.61496454], dtype=float32),
#  array([0.3991817 , 0.60081834], dtype=float32),
#  array([0.611946, 0.388054], dtype=float32),
#  array([0.5119274 , 0.48807257], dtype=float32),
#  array([0.53504896, 0.46495098], dtype=float32),
#  array([0.28288966, 0.7171104 ], dtype=float32),
#  array([0.3125557, 0.6874443], dtype=float32),
#  array([0.48465723, 0.5153428 ], dtype=float32),
#  array([0.33172315, 0.66827685], dtype=float32),
#  array([0.862768  , 0.13723199], dtype=float32),
#  array([0.87874246, 0.12125758], dtype=float32),
#  array([0.38976538, 0.6102347 ], dtype=float32),
#  array([0.52129877, 0.4787013 ], dtype=float32),
#  array([0.61290276, 0.38709715], dtype=float32),
#  array([0.80702466, 0.19297536], dtype=float32),
#  array([0.7045235 , 0.29547653], dtype=float32),
#  array([0.5663164 , 0.43368357], dtype=float32),
#  array([0.44850564, 0.55149436], dtype=float32),
#  array([0.2615127, 0.7384873], dtype=float32),
#  array([0.5565332 , 0.44346678], dtype=float32),
#  array([0.43723884, 0.5627612 ], dtype=float32),
#  array([0.3039952, 0.6960048], dtype=float32),
#  array([0.3670656 , 0.63293433], dtype=float32),
#  array([0.33210555, 0.6678944 ], dtype=float32),
#  array([0.35397893, 0.64602107], dtype=float32),
#  array([0.14799634, 0.85200363], dtype=float32),
#  array([0.5047123 , 0.49528775], dtype=float32),
#  array([0.35684177, 0.64315826], dtype=float32),
#  array([0.43691242, 0.5630876 ], dtype=float32),
#  array([0.35648414, 0.6435159 ], dtype=float32),
#  array([0.4681713 , 0.53182864], dtype=float32),
#  array([0.35823327, 0.6417668 ], dtype=float32),
#  array([0.7154464 , 0.28455353], dtype=float32),
#  array([0.4528641, 0.5471359], dtype=float32),
#  array([0.26346883, 0.73653114], dtype=float32),
#  array([0.4119546, 0.5880454], dtype=float32),
#  array([0.42866066, 0.57133937], dtype=float32),
#  array([0.3561114, 0.6438886], dtype=float32),
#  array([0.34734702, 0.65265304], dtype=float32),
#  array([0.37846   , 0.62153995], dtype=float32),
#  array([0.3621441, 0.6378558], dtype=float32),
#  array([0.49888277, 0.5011172 ], dtype=float32),
#  array([0.9445953 , 0.05540475], dtype=float32),
#  array([0.39942548, 0.60057455], dtype=float32),
#  array([0.36475542, 0.6352446 ], dtype=float32),
#  array([0.55181515, 0.4481848 ], dtype=float32),
#  array([0.83041984, 0.1695802 ], dtype=float32),
#  array([0.40409   , 0.59590995], dtype=float32),
#  array([0.5119325 , 0.48806745], dtype=float32),
#  array([0.5817844 , 0.41821554], dtype=float32),
#  array([0.43105367, 0.56894636], dtype=float32),
#  array([0.05922383, 0.9407762 ], dtype=float32),
#  array([0.3744293, 0.6255707], dtype=float32),
#  array([0.44870862, 0.5512914 ], dtype=float32),
#  array([0.3818921, 0.6181079], dtype=float32),
#  array([0.49480984, 0.5051902 ], dtype=float32),
#  array([0.4059521 , 0.59404784], dtype=float32),
#  array([0.39836633, 0.60163367], dtype=float32),
#  array([0.3945795, 0.6054206], dtype=float32),
#  array([0.8878183 , 0.11218174], dtype=float32),
#  array([0.39692676, 0.60307324], dtype=float32),
#  array([0.37322104, 0.62677896], dtype=float32),
#  array([0.5915752, 0.4084248], dtype=float32),
#  array([0.40206587, 0.5979341 ], dtype=float32),
#  array([0.57423794, 0.4257621 ], dtype=float32),
#  array([0.50929   , 0.49071005], dtype=float32),
#  array([0.4144645 , 0.58553547], dtype=float32),
#  array([0.54834723, 0.4516528 ], dtype=float32),
#  array([0.5587893 , 0.44121066], dtype=float32),
#  array([0.4003316 , 0.59966844], dtype=float32),
#  array([0.58393395, 0.4160661 ], dtype=float32),
#  array([0.14783092, 0.85216904], dtype=float32),
#  array([0.45729423, 0.5427057 ], dtype=float32),
#  array([0.3149088, 0.6850912], dtype=float32),
#  array([0.29672563, 0.70327437], dtype=float32),
#  array([0.52396935, 0.4760306 ], dtype=float32),
#  array([0.47199923, 0.5280008 ], dtype=float32),
#  array([0.4722742 , 0.52772576], dtype=float32),
#  array([0.43393603, 0.56606394], dtype=float32),
#  array([0.41898778, 0.58101225], dtype=float32),
#  array([0.45269883, 0.5473012 ], dtype=float32),
#  array([0.30385238, 0.6961476 ], dtype=float32),
#  array([0.68978596, 0.31021404], dtype=float32),
#  array([0.40793246, 0.59206754], dtype=float32),
#  array([0.23480937, 0.7651906 ], dtype=float32),
#  array([0.2075993, 0.7924008], dtype=float32),
#  array([0.7795151 , 0.22048493], dtype=float32),
#  array([0.2369726 , 0.76302737], dtype=float32),
#  array([0.4801823 , 0.51981777], dtype=float32),
#  array([0.3619715 , 0.63802856], dtype=float32),
#  array([0.3619715 , 0.63802856], dtype=float32),
#  array([0.4717259, 0.528274 ], dtype=float32),
#  array([0.5531713 , 0.44682875], dtype=float32),
#  array([0.5452099, 0.4547901], dtype=float32),
#  array([0.9320927 , 0.06790729], dtype=float32),
#  array([0.40607414, 0.5939258 ], dtype=float32),
#  array([0.5508759 , 0.44912413], dtype=float32),
#  array([0.44413212, 0.55586785], dtype=float32),
#  array([0.974428  , 0.02557195], dtype=float32),
#  array([0.94623524, 0.05376476], dtype=float32),
#  array([0.37039855, 0.6296014 ], dtype=float32),
#  array([0.32020608, 0.6797939 ], dtype=float32),
#  array([0.48723733, 0.5127626 ], dtype=float32),
#  array([0.26434815, 0.7356518 ], dtype=float32),
#  array([0.35197237, 0.64802754], dtype=float32),
#  array([0.4906735, 0.5093265], dtype=float32),
#  array([0.28457075, 0.71542925], dtype=float32),
#  array([0.5878187, 0.4121813], dtype=float32),
#  array([0.29660293, 0.7033971 ], dtype=float32),
#  array([0.31011522, 0.6898847 ], dtype=float32),
#  array([0.17653541, 0.8234646 ], dtype=float32),
#  array([0.3364213, 0.6635787], dtype=float32),
#  array([0.3966576, 0.6033425], dtype=float32),
#  array([0.43035546, 0.5696445 ], dtype=float32),
#  array([0.5112357 , 0.48876432], dtype=float32),
#  array([0.5325213 , 0.46747875], dtype=float32),
#  array([0.7084783, 0.2915217], dtype=float32),
#  array([0.6605453, 0.3394547], dtype=float32),
#  array([0.48441705, 0.5155829 ], dtype=float32),
#  array([0.26016802, 0.7398319 ], dtype=float32),
#  array([0.71630204, 0.283698  ], dtype=float32),
#  array([0.30534178, 0.6946582 ], dtype=float32),
#  array([0.32451603, 0.67548394], dtype=float32),
#  array([0.32694727, 0.6730527 ], dtype=float32),
#  array([0.46004343, 0.5399565 ], dtype=float32),
#  array([0.33858332, 0.66141665], dtype=float32),
#  array([0.11345603, 0.8865439 ], dtype=float32),
#  array([0.47002587, 0.52997416], dtype=float32),
#  array([0.55370045, 0.44629958], dtype=float32),
#  array([0.3313374 , 0.66866255], dtype=float32),
#  array([0.3698803, 0.6301197], dtype=float32),
#  array([0.5590368, 0.4409632], dtype=float32),
#  array([0.6100418 , 0.38995814], dtype=float32),
#  array([0.40774557, 0.59225446], dtype=float32),
#  array([0.53278303, 0.46721697], dtype=float32),
#  array([0.13275671, 0.86724323], dtype=float32),
#  array([0.64995533, 0.35004473], dtype=float32),
#  array([0.5925738 , 0.40742618], dtype=float32),
#  array([0.52689606, 0.47310388], dtype=float32),
#  array([0.5421752 , 0.45782486], dtype=float32),
#  array([0.293937  , 0.70606303], dtype=float32),
#  array([0.9876886, 0.0123114], dtype=float32),
#  array([0.54465085, 0.45534912], dtype=float32),
#  array([0.4626715, 0.5373285], dtype=float32),
#  array([0.46341613, 0.53658384], dtype=float32),
#  array([0.46036932, 0.5396307 ], dtype=float32),
#  array([0.38937035, 0.6106297 ], dtype=float32),
#  array([4.6223644e-04, 9.9953783e-01], dtype=float32),
#  array([0.30337444, 0.6966256 ], dtype=float32),
#  array([0.40440094, 0.59559906], dtype=float32),
#  array([0.33658022, 0.66341984], dtype=float32),
#  array([0.5488653 , 0.45113465], dtype=float32),
#  array([0.4952486, 0.5047514], dtype=float32),
#  array([0.40773913, 0.5922609 ], dtype=float32),
#  array([0.42684048, 0.5731595 ], dtype=float32),
#  array([0.4334037, 0.5665962], dtype=float32),
#  array([0.37682155, 0.62317836], dtype=float32),
#  array([0.99690324, 0.00309675], dtype=float32),
#  array([0.5423672 , 0.45763278], dtype=float32),
#  array([0.511963  , 0.48803693], dtype=float32),
#  array([0.33749798, 0.662502  ], dtype=float32),
#  array([0.19628306, 0.8037169 ], dtype=float32),
#  array([0.39311832, 0.6068817 ], dtype=float32),
#  array([0.7703961 , 0.22960392], dtype=float32),
#  array([0.42268917, 0.5773108 ], dtype=float32),
#  array([0.5018277 , 0.49817228], dtype=float32),
#  array([0.46581534, 0.5341847 ], dtype=float32),
#  array([0.46188372, 0.5381163 ], dtype=float32),
#  array([0.7398474, 0.2601526], dtype=float32),
#  array([0.3688991 , 0.63110095], dtype=float32),
#  array([0.588867, 0.411133], dtype=float32),
#  array([0.49265102, 0.507349  ], dtype=float32),
#  array([0.28474456, 0.71525544], dtype=float32),
#  array([0.25694796, 0.74305207], dtype=float32),
#  array([0.35222748, 0.64777255], dtype=float32),
#  array([0.37464467, 0.62535536], dtype=float32),
#  array([0.49835405, 0.501646  ], dtype=float32),
#  array([0.25274417, 0.7472558 ], dtype=float32),
#  array([0.38873687, 0.6112631 ], dtype=float32),
#  array([0.26610982, 0.7338901 ], dtype=float32),
#  array([0.3960099 , 0.60399014], dtype=float32),
#  array([0.44493577, 0.5550642 ], dtype=float32),
#  array([0.50408983, 0.49591023], dtype=float32),
#  array([0.30449283, 0.69550717], dtype=float32),
#  array([0.2685367 , 0.73146325], dtype=float32),
#  array([0.43275172, 0.5672483 ], dtype=float32),
#  array([0.54880965, 0.45119038], dtype=float32),
#  array([0.5294173, 0.4705827], dtype=float32),
#  array([0.48930168, 0.5106983 ], dtype=float32),
#  array([0.34998322, 0.6500168 ], dtype=float32),
#  array([0.45240846, 0.54759157], dtype=float32),
#  array([0.18030892, 0.8196911 ], dtype=float32),
#  array([0.48217082, 0.5178291 ], dtype=float32),
#  array([0.3585052 , 0.64149487], dtype=float32),
#  array([0.43896076, 0.5610392 ], dtype=float32),
#  array([0.5552056 , 0.44479448], dtype=float32),
#  array([0.8172884, 0.1827116], dtype=float32),
#  array([0.49090368, 0.5090964 ], dtype=float32),
#  array([0.37367126, 0.6263287 ], dtype=float32),
#  array([0.5310671, 0.4689329], dtype=float32),
#  array([0.42137766, 0.57862234], dtype=float32),
#  array([0.48220152, 0.5177984 ], dtype=float32),
#  array([0.27468485, 0.72531515], dtype=float32),
#  array([0.37924087, 0.6207591 ], dtype=float32),
#  array([0.34171343, 0.6582866 ], dtype=float32),
#  array([0.37572804, 0.6242719 ], dtype=float32),
#  array([0.27697793, 0.72302204], dtype=float32),
#  array([0.46457788, 0.5354221 ], dtype=float32),
#  array([0.34480304, 0.6551969 ], dtype=float32),
#  array([0.4185344, 0.5814656], dtype=float32),
#  array([0.41195294, 0.588047  ], dtype=float32),
#  array([0.4772004, 0.5227997], dtype=float32),
#  array([0.46136042, 0.5386395 ], dtype=float32),
#  array([0.44047382, 0.5595261 ], dtype=float32),
#  array([0.3170902, 0.6829098], dtype=float32),
#  array([0.3405582, 0.6594418], dtype=float32),
#  array([0.5012941, 0.4987059], dtype=float32),
#  array([0.41884103, 0.5811589 ], dtype=float32),
#  array([0.5764627 , 0.42353734], dtype=float32),
#  array([0.98511446, 0.01488557], dtype=float32),
#  array([0.31123182, 0.68876815], dtype=float32),
#  array([0.41830453, 0.58169544], dtype=float32),
#  array([0.37147322, 0.62852675], dtype=float32),
#  array([0.2521355 , 0.74786454], dtype=float32),
#  array([0.5456523 , 0.45434776], dtype=float32),
#  array([0.4281524, 0.5718476], dtype=float32),
#  array([0.22528917, 0.7747109 ], dtype=float32),
#  array([0.51145816, 0.4885419 ], dtype=float32),
#  array([0.3931245 , 0.60687554], dtype=float32),
#  array([9.9913764e-01, 8.6229382e-04], dtype=float32),
#  array([0.45066053, 0.5493395 ], dtype=float32),
#  array([0.60961163, 0.39038837], dtype=float32),
#  array([0.42771292, 0.5722871 ], dtype=float32),
#  array([0.4991698 , 0.50083023], dtype=float32),
#  array([0.25537264, 0.7446273 ], dtype=float32),
#  array([0.28736383, 0.7126361 ], dtype=float32),
#  array([0.26434815, 0.7356518 ], dtype=float32),
#  array([0.39891425, 0.6010858 ], dtype=float32),
#  array([0.37800285, 0.6219971 ], dtype=float32),
#  array([0.5321844 , 0.46781558], dtype=float32),
#  array([0.7604475 , 0.23955251], dtype=float32),
#  array([0.4312169, 0.5687831], dtype=float32),
#  array([0.3089685 , 0.69103146], dtype=float32),
#  array([0.4587735, 0.5412265], dtype=float32),
#  array([0.45585343, 0.54414654], dtype=float32),
#  array([0.3518233 , 0.64817667], dtype=float32),
#  array([0.39916268, 0.6008373 ], dtype=float32),
#  array([0.2437555, 0.7562445], dtype=float32),
#  array([0.43983635, 0.5601636 ], dtype=float32),
#  array([0.74736   , 0.25263992], dtype=float32),
#  array([0.5270016 , 0.47299844], dtype=float32),
#  array([0.42369506, 0.576305  ], dtype=float32),
#  array([0.22187899, 0.778121  ], dtype=float32),
#  array([0.2397502 , 0.76024973], dtype=float32),
#  array([0.38726336, 0.6127366 ], dtype=float32),
#  array([0.39634308, 0.60365695], dtype=float32),
#  array([0.35994664, 0.6400534 ], dtype=float32),
#  array([0.52968764, 0.4703123 ], dtype=float32),
#  array([0.3135169, 0.686483 ], dtype=float32),
#  array([0.38650107, 0.6134989 ], dtype=float32),
#  array([0.7241031 , 0.27589694], dtype=float32),
#  array([0.18872413, 0.8112759 ], dtype=float32),
#  array([0.31427017, 0.68572986], dtype=float32),
#  array([0.29040653, 0.7095935 ], dtype=float32),
#  array([0.38697788, 0.6130221 ], dtype=float32),
#  array([0.37349394, 0.6265061 ], dtype=float32),
#  array([0.64995503, 0.35004497], dtype=float32),
#  array([0.66697985, 0.33302015], dtype=float32),
#  array([0.6154036 , 0.38459635], dtype=float32),
#  array([0.407551  , 0.59244907], dtype=float32),
#  array([0.41392606, 0.58607394], dtype=float32),
#  array([0.36281192, 0.6371881 ], dtype=float32),
#  array([0.35202065, 0.6479793 ], dtype=float32),
#  array([0.3515509 , 0.64844906], dtype=float32),
#  array([0.57160044, 0.4283996 ], dtype=float32),
#  array([0.36039823, 0.6396018 ], dtype=float32),
#  array([0.4904388, 0.5095612], dtype=float32),
#  array([0.59694964, 0.40305036], dtype=float32),
#  array([0.14930645, 0.8506935 ], dtype=float32),
#  array([0.32803652, 0.67196345], dtype=float32),
#  array([0.7433384 , 0.25666165], dtype=float32),
#  array([0.15822932, 0.8417707 ], dtype=float32),
#  array([0.18956226, 0.8104378 ], dtype=float32),
#  array([0.5624078, 0.4375922], dtype=float32),
#  array([0.47549206, 0.5245079 ], dtype=float32),
#  array([0.51378536, 0.48621464], dtype=float32),
#  array([0.35139668, 0.6486033 ], dtype=float32),
#  array([0.58166367, 0.41833633], dtype=float32),
#  array([0.40817213, 0.5918278 ], dtype=float32),
#  array([0.3278171, 0.672183 ], dtype=float32),
#  array([0.49942788, 0.5005721 ], dtype=float32),
#  array([0.1515612, 0.8484388], dtype=float32),
#  array([0.29738438, 0.7026156 ], dtype=float32),
#  array([0.43016636, 0.5698336 ], dtype=float32),
#  array([0.47717065, 0.5228293 ], dtype=float32),
#  array([0.21487997, 0.78512   ], dtype=float32),
#  array([0.25818074, 0.74181926], dtype=float32),
#  array([0.3574733 , 0.64252675], dtype=float32),
#  array([0.49618843, 0.50381154], dtype=float32),
#  array([0.72727334, 0.27272663], dtype=float32),
#  array([0.39716992, 0.6028301 ], dtype=float32),
#  array([0.41392502, 0.586075  ], dtype=float32),
#  array([0.9843627 , 0.01563735], dtype=float32),
#  array([0.5192591 , 0.48074085], dtype=float32),
#  array([0.4345532, 0.5654468], dtype=float32),
#  array([0.50051945, 0.4994806 ], dtype=float32),
#  array([0.93206173, 0.06793819], dtype=float32),
#  array([0.21839611, 0.78160393], dtype=float32),
#  array([0.5402988, 0.4597012], dtype=float32),
#  array([0.6326103 , 0.36738962], dtype=float32),
#  array([0.478665, 0.521335], dtype=float32),
#  array([0.4106573, 0.5893427], dtype=float32),
#  array([0.32228422, 0.6777157 ], dtype=float32),
#  array([0.28105274, 0.71894723], dtype=float32),
#  array([0.3743098, 0.6256902], dtype=float32),
#  array([0.27833515, 0.7216649 ], dtype=float32),
#  array([0.1368311 , 0.86316884], dtype=float32),
#  array([0.3704, 0.6296], dtype=float32),
#  array([0.19504356, 0.80495644], dtype=float32),
#  array([0.5141825 , 0.48581746], dtype=float32),
#  array([0.46336323, 0.5366368 ], dtype=float32),
#  array([0.5533281 , 0.44667193], dtype=float32),
#  array([0.5059832, 0.4940168], dtype=float32),
#  array([0.5222539 , 0.47774607], dtype=float32),
#  array([0.47723722, 0.5227627 ], dtype=float32),
#  array([0.30028027, 0.6997197 ], dtype=float32),
#  array([0.30028027, 0.6997197 ], dtype=float32),
#  array([0.32921416, 0.67078584], dtype=float32),
#  array([0.45968446, 0.5403155 ], dtype=float32),
#  array([0.5738995 , 0.42610043], dtype=float32),
#  array([0.2701849 , 0.72981507], dtype=float32),
#  array([0.50818133, 0.49181864], dtype=float32),
#  array([0.4236021, 0.5763979], dtype=float32),
#  array([0.35099626, 0.64900374], dtype=float32),
#  array([0.49288625, 0.50711375], dtype=float32),
#  array([0.2566884 , 0.74331164], dtype=float32),
#  array([0.41910115, 0.5808988 ], dtype=float32),
#  array([0.57133067, 0.42866936], dtype=float32),
#  array([0.29221126, 0.7077887 ], dtype=float32),
#  array([0.8487168 , 0.15128328], dtype=float32),
#  array([0.26476997, 0.73523   ], dtype=float32),
#  array([0.2962408 , 0.70375925], dtype=float32),
#  array([0.44006887, 0.5599311 ], dtype=float32),
#  array([0.6445862 , 0.35541382], dtype=float32),
#  array([0.35545155, 0.6445484 ], dtype=float32),
#  array([0.41720036, 0.58279973], dtype=float32),
#  array([0.31738448, 0.6826156 ], dtype=float32),
#  array([0.46729666, 0.5327034 ], dtype=float32),
#  array([0.0162634, 0.9837366], dtype=float32),
#  array([0.42590517, 0.57409483], dtype=float32),
#  array([0.27312514, 0.7268749 ], dtype=float32),
#  array([0.26707205, 0.7329279 ], dtype=float32),
#  array([0.38726082, 0.61273915], dtype=float32),
#  array([0.83513737, 0.16486268], dtype=float32),
#  array([0.44491634, 0.5550837 ], dtype=float32),
#  array([0.46770313, 0.5322968 ], dtype=float32),
#  array([0.22904941, 0.7709506 ], dtype=float32),
#  array([0.525879  , 0.47412097], dtype=float32),
#  array([0.36756548, 0.63243455], dtype=float32),
#  array([0.33398342, 0.6660166 ], dtype=float32),
#  array([0.3274643, 0.6725357], dtype=float32),
#  array([0.2734035, 0.7265965], dtype=float32),
#  array([0.3467735, 0.6532265], dtype=float32),
#  array([0.44432682, 0.5556732 ], dtype=float32),
#  array([0.5712922 , 0.42870772], dtype=float32),
#  array([0.49241492, 0.5075851 ], dtype=float32),
#  array([0.50731456, 0.49268547], dtype=float32),
#  array([0.48630062, 0.5136994 ], dtype=float32),
#  array([0.45363182, 0.5463682 ], dtype=float32),
#  array([0.57492906, 0.42507094], dtype=float32),
#  array([0.18945017, 0.81054986], dtype=float32),
#  array([0.21038052, 0.7896195 ], dtype=float32),
#  array([0.46957737, 0.5304227 ], dtype=float32),
#  array([0.37187463, 0.62812537], dtype=float32),
#  array([0.5102935 , 0.48970652], dtype=float32),
#  array([0.58330214, 0.41669783], dtype=float32),
#  array([0.548913, 0.451087], dtype=float32),
#  array([0.38878515, 0.61121494], dtype=float32),
#  array([0.43733585, 0.56266415], dtype=float32),
#  array([0.42668733, 0.5733126 ], dtype=float32),
#  array([0.4468308 , 0.55316925], dtype=float32),
#  array([0.695151, 0.304849], dtype=float32),
#  array([0.9961604 , 0.00383965], dtype=float32),
#  array([0.4487283 , 0.55127174], dtype=float32),
#  array([0.35977995, 0.64022   ], dtype=float32),
#  array([0.3425552 , 0.65744483], dtype=float32),
#  array([0.62589186, 0.3741081 ], dtype=float32),
#  array([0.87096995, 0.12902996], dtype=float32),
#  array([0.9468842, 0.0531158], dtype=float32),
#  array([0.2118231 , 0.78817695], dtype=float32),
#  array([0.3106087 , 0.68939126], dtype=float32),
#  array([0.34650132, 0.65349865], dtype=float32),
#  array([0.6294949 , 0.37050512], dtype=float32),
#  array([0.44250274, 0.55749726], dtype=float32),
#  array([0.7857499 , 0.21425012], dtype=float32),
#  array([0.4631414 , 0.53685856], dtype=float32),
#  array([0.42492405, 0.575076  ], dtype=float32),
#  array([0.42639711, 0.5736029 ], dtype=float32),
#  array([0.5391049, 0.4608951], dtype=float32),
#  array([0.45896295, 0.541037  ], dtype=float32),
#  array([0.19246423, 0.80753577], dtype=float32),
#  array([0.33997783, 0.6600222 ], dtype=float32),
#  array([0.11544555, 0.8845545 ], dtype=float32),
#  array([0.52172136, 0.47827858], dtype=float32),
#  array([0.27286375, 0.72713625], dtype=float32),
#  array([0.35821128, 0.64178866], dtype=float32),
#  array([0.3340686, 0.6659314], dtype=float32),
#  array([0.45557356, 0.5444265 ], dtype=float32),
#  array([0.43666938, 0.5633306 ], dtype=float32),
#  array([0.423109  , 0.57689095], dtype=float32),
#  array([0.43844298, 0.56155705], dtype=float32),
#  array([0.20122474, 0.7987752 ], dtype=float32),
#  array([0.44171253, 0.5582875 ], dtype=float32),
#  array([0.4407322, 0.5592678], dtype=float32),
#  array([0.07774016, 0.9222598 ], dtype=float32),
#  array([0.4377079 , 0.56229204], dtype=float32),
#  array([0.55023646, 0.44976354], dtype=float32),
#  array([0.6452853 , 0.35471466], dtype=float32),
#  array([0.6160751, 0.3839249], dtype=float32),
#  array([0.32144672, 0.67855334], dtype=float32),
#  array([0.19915491, 0.8008451 ], dtype=float32),
#  array([0.54625326, 0.4537468 ], dtype=float32),
#  array([0.61020255, 0.38979748], dtype=float32),
#  array([0.3711169 , 0.62888306], dtype=float32),
#  array([0.3916786, 0.6083214], dtype=float32),
#  array([0.9969908 , 0.00300914], dtype=float32),
#  array([0.3471711, 0.6528289], dtype=float32),
#  array([0.13644938, 0.8635506 ], dtype=float32),
#  array([0.13362654, 0.8663734 ], dtype=float32),
#  array([0.48868245, 0.5113176 ], dtype=float32),
#  array([0.3775857 , 0.62241423], dtype=float32),
#  array([0.40309685, 0.59690315], dtype=float32),
#  array([0.5527792 , 0.44722086], dtype=float32),
#  array([0.45148298, 0.54851705], dtype=float32),
#  array([0.46767384, 0.5323262 ], dtype=float32),
#  array([0.20697454, 0.7930255 ], dtype=float32),
#  array([0.4567639 , 0.54323614], dtype=float32),
#  array([0.5912433 , 0.40875667], dtype=float32),
#  array([0.2597656, 0.7402343], dtype=float32),
#  array([0.38451132, 0.61548865], dtype=float32),
#  array([0.20554456, 0.7944554 ], dtype=float32),
#  array([0.41393194, 0.5860681 ], dtype=float32),
#  array([0.26690763, 0.73309237], dtype=float32),
#  array([0.43133867, 0.56866133], dtype=float32),
#  array([0.38368234, 0.6163177 ], dtype=float32),
#  array([0.36273545, 0.63726455], dtype=float32),
#  array([0.43527386, 0.5647261 ], dtype=float32),
#  array([0.10715999, 0.89284   ], dtype=float32),
#  array([0.38561502, 0.61438495], dtype=float32),
#  array([0.87204325, 0.12795678], dtype=float32),
#  array([0.5194555 , 0.48054454], dtype=float32),
#  array([0.49985516, 0.5001449 ], dtype=float32),
#  array([0.20945229, 0.7905477 ], dtype=float32),
#  array([0.35410494, 0.6458951 ], dtype=float32),
#  array([0.4020123, 0.5979877], dtype=float32),
#  array([0.48644844, 0.51355165], dtype=float32),
#  array([0.63653445, 0.36346555], dtype=float32),
#  array([0.4803673 , 0.51963276], dtype=float32),
#  array([0.25482178, 0.74517816], dtype=float32),
#  array([0.6126511 , 0.38734892], dtype=float32),
#  array([0.5785683 , 0.42143175], dtype=float32),
#  array([0.40305716, 0.59694284], dtype=float32),
#  array([0.10287209, 0.8971279 ], dtype=float32),
#  array([0.04371471, 0.95628524], dtype=float32),
#  array([0.34171635, 0.65828365], dtype=float32),
#  array([0.58274305, 0.417257  ], dtype=float32),
#  array([0.5464592 , 0.45354077], dtype=float32),
#  array([0.6184905 , 0.38150948], dtype=float32),
#  array([0.27839482, 0.7216052 ], dtype=float32),
#  array([0.40335444, 0.5966456 ], dtype=float32),
#  array([0.33298308, 0.6670169 ], dtype=float32),
#  array([0.42484963, 0.57515043], dtype=float32),
#  array([0.5700774 , 0.42992264], dtype=float32),
#  array([0.29683432, 0.7031657 ], dtype=float32),
#  array([0.3815519 , 0.61844814], dtype=float32),
#  array([0.30993506, 0.6900649 ], dtype=float32),
#  array([0.46196616, 0.53803384], dtype=float32),
#  array([0.6335965 , 0.36640352], dtype=float32),
#  array([0.5267019 , 0.47329807], dtype=float32),
#  array([0.4999017, 0.5000983], dtype=float32),
#  array([0.45669568, 0.5433043 ], dtype=float32),
#  array([0.255357  , 0.74464303], dtype=float32),
#  array([0.5678511 , 0.43214887], dtype=float32),
#  array([0.49440223, 0.50559783], dtype=float32),
#  array([0.20997581, 0.79002416], dtype=float32),
#  array([0.3437879 , 0.65621203], dtype=float32),
#  array([0.3198583, 0.6801417], dtype=float32),
#  array([0.39679998, 0.60319996], dtype=float32),
#  array([0.44837153, 0.5516285 ], dtype=float32),
#  array([0.6266732, 0.3733268], dtype=float32),
#  array([0.77164704, 0.228353  ], dtype=float32),
#  array([0.5304838 , 0.46951625], dtype=float32),
#  array([0.50605243, 0.4939475 ], dtype=float32),
#  array([0.35077986, 0.6492201 ], dtype=float32),
#  array([0.3251103 , 0.67488974], dtype=float32),
#  array([0.44854528, 0.55145466], dtype=float32),
#  array([0.40157953, 0.5984205 ], dtype=float32),
#  array([0.21569628, 0.78430367], dtype=float32),
#  array([0.35580346, 0.6441965 ], dtype=float32),
#  array([0.99893147, 0.00106849], dtype=float32),
#  array([0.8684253 , 0.13157469], dtype=float32),
#  array([0.9277269 , 0.07227305], dtype=float32),
#  array([0.243338, 0.756662], dtype=float32),
#  array([0.7900635 , 0.20993656], dtype=float32),
#  array([0.6251131 , 0.37488684], dtype=float32),
#  array([0.97042996, 0.02957007], dtype=float32),
#  array([0.37283772, 0.6271622 ], dtype=float32),
#  array([0.42487672, 0.5751233 ], dtype=float32),
#  array([0.45526606, 0.54473394], dtype=float32),
#  array([0.20192203, 0.798078  ], dtype=float32),
#  array([0.5909057, 0.4090943], dtype=float32),
#  array([0.7541505 , 0.24584943], dtype=float32),
#  array([0.37726513, 0.6227349 ], dtype=float32),
#  array([0.29682365, 0.7031764 ], dtype=float32),
#  array([0.503401, 0.496599], dtype=float32),
#  array([0.48849982, 0.5115002 ], dtype=float32),
#  array([0.44301638, 0.5569836 ], dtype=float32),
#  array([0.4847418 , 0.51525825], dtype=float32),
#  array([0.4724713 , 0.52752876], dtype=float32),
#  array([0.44244227, 0.5575577 ], dtype=float32),
#  array([0.42137605, 0.57862395], dtype=float32),
#  array([0.33251125, 0.6674888 ], dtype=float32),
#  array([0.5886685, 0.4113315], dtype=float32),
#  array([0.4074582 , 0.59254175], dtype=float32),
#  array([0.4472942 , 0.55270576], dtype=float32),
#  array([0.3147848, 0.6852152], dtype=float32),
#  array([0.80573314, 0.19426684], dtype=float32),
#  array([0.35777736, 0.64222264], dtype=float32),
#  array([0.38163152, 0.6183685 ], dtype=float32),
#  array([0.27259606, 0.7274039 ], dtype=float32),
#  array([0.36795795, 0.632042  ], dtype=float32),
#  array([0.39794382, 0.60205615], dtype=float32),
#  array([0.34684983, 0.6531501 ], dtype=float32),
#  array([0.30184063, 0.69815934], dtype=float32),
#  array([0.26827413, 0.7317259 ], dtype=float32),
#  array([0.54082733, 0.45917276], dtype=float32),
#  array([0.46176183, 0.5382381 ], dtype=float32),
#  array([0.34677216, 0.6532278 ], dtype=float32),
#  array([0.37876856, 0.6212314 ], dtype=float32),
#  array([0.430219, 0.569781], dtype=float32),
#  array([0.34805134, 0.6519487 ], dtype=float32),
#  array([0.35800946, 0.64199054], dtype=float32),
#  array([0.5389774 , 0.46102268], dtype=float32),
#  array([0.58661795, 0.41338205], dtype=float32),
#  array([0.40520582, 0.59479415], dtype=float32),
#  array([0.38078755, 0.6192124 ], dtype=float32),
#  array([0.38775367, 0.61224633], dtype=float32),
#  array([0.19091336, 0.8090867 ], dtype=float32),
#  array([0.45198306, 0.548017  ], dtype=float32),
#  array([0.15311348, 0.8468865 ], dtype=float32),
#  array([0.28092137, 0.7190786 ], dtype=float32),
#  array([0.42255825, 0.57744175], dtype=float32),
#  array([0.6286504, 0.3713496], dtype=float32),
#  array([0.20555031, 0.7944496 ], dtype=float32),
#  array([0.65585715, 0.34414288], dtype=float32),
#  array([0.6527106, 0.3472894], dtype=float32),
#  array([0.4411954, 0.5588046], dtype=float32),
#  array([0.34473598, 0.6552641 ], dtype=float32),
#  array([0.5389444 , 0.46105558], dtype=float32),
#  array([0.3844658, 0.6155342], dtype=float32),
#  array([0.36224422, 0.6377558 ], dtype=float32),
#  array([0.36844152, 0.6315584 ], dtype=float32),
#  array([0.33562604, 0.66437393], dtype=float32),
#  array([0.45552814, 0.54447186], dtype=float32),
#  array([0.4584919, 0.5415081], dtype=float32),
#  array([0.32186326, 0.67813677], dtype=float32),
#  array([0.5381456, 0.4618544], dtype=float32),
#  array([0.29889792, 0.7011021 ], dtype=float32),
#  array([0.27433226, 0.7256677 ], dtype=float32),
#  array([0.22520304, 0.77479696], dtype=float32),
#  array([0.6466341, 0.353366 ], dtype=float32),
#  array([0.52404326, 0.47595677], dtype=float32),
#  array([0.46851808, 0.53148186], dtype=float32),
#  array([0.4920171 , 0.50798297], dtype=float32),
#  array([0.5612066 , 0.43879348], dtype=float32),
#  array([0.3651578, 0.6348422], dtype=float32),
#  array([0.4719972 , 0.52800274], dtype=float32),
#  array([0.4202215 , 0.57977855], dtype=float32),
#  array([0.27108335, 0.72891665], dtype=float32),
#  array([0.3104288, 0.6895712], dtype=float32),
#  array([0.4829319, 0.5170681], dtype=float32),
#  array([0.39131656, 0.60868347], dtype=float32)]

# %%
test = [pred_data[i][3][0] for i in range(len(pred_data))]
test
# Out:
# [0.49679807,
#  0.44773072,
#  0.37208945,
#  0.4177292,
#  0.15665025,
#  0.481279,
#  0.3549384,
#  0.4487762,
#  0.3396108,
#  0.59259963,
#  0.3225041,
#  0.51031446,
#  0.5158468,
#  0.7968285,
#  0.5516662,
#  0.45495462,
#  0.45943114,
#  0.31824842,
#  0.40700942,
#  0.4221701,
#  0.46545285,
#  0.170416,
#  0.32102212,
#  0.7462275,
#  0.50068885,
#  0.2944002,
#  0.5759083,
#  0.26614434,
#  0.20246737,
#  0.57282525,
#  0.98198986,
#  0.44121385,
#  0.68642175,
#  0.27666262,
#  0.3722229,
#  0.45570093,
#  0.42283517,
#  0.42463994,
#  0.48861513,
#  0.44602555,
#  0.46618062,
#  0.26708966,
#  0.22056052,
#  0.1957829,
#  0.38704702,
#  0.2524055,
#  0.577657,
#  0.98871815,
#  0.4615351,
#  0.50565565,
#  0.26957905,
#  0.43304533,
#  0.7936428,
#  0.3350533,
#  0.45276296,
#  0.36564085,
#  0.3272442,
#  0.4657933,
#  0.2485024,
#  0.9242365,
#  0.48615074,
#  0.75182503,
#  0.3324455,
#  0.3713097,
#  0.39937276,
#  0.4009985,
#  0.54883385,
#  0.29889438,
#  0.51488435,
#  0.26450452,
#  0.3275936,
#  0.42048314,
#  0.40657312,
#  0.46476457,
#  0.47016966,
#  0.17344593,
#  0.8535881,
#  0.8835661,
#  0.4046533,
#  0.28814855,
#  0.27645567,
#  0.4091998,
#  0.3879654,
#  0.78389287,
#  0.39309782,
#  0.1567237,
#  0.50645393,
#  0.44264138,
#  0.5435989,
#  0.3731589,
#  0.5246808,
#  0.6427101,
#  0.4863609,
#  0.17709059,
#  0.37354124,
#  0.42792848,
#  0.3322046,
#  0.48969123,
#  0.37385792,
#  0.42610455,
#  0.4992233,
#  0.50051516,
#  0.5350393,
#  0.711247,
#  0.35574946,
#  0.4686752,
#  0.36128092,
#  0.81163627,
#  0.5057788,
#  0.19770826,
#  0.53557575,
#  0.36239836,
#  0.1918783,
#  0.33106235,
#  0.39676172,
#  0.397267,
#  0.5664822,
#  0.817821,
#  0.073355794,
#  0.5263947,
#  0.43786982,
#  0.36536297,
#  0.32323816,
#  0.30809587,
#  0.4219399,
#  0.3601664,
#  0.62378746,
#  0.4048291,
#  0.54916126,
#  0.3395785,
#  0.4715112,
#  0.3096186,
#  0.42905986,
#  0.38357863,
#  0.35476947,
#  0.52172136,
#  0.35616753,
#  0.9936888,
#  0.56197053,
#  0.46982333,
#  0.43862432,
#  0.093184955,
#  0.94384176,
#  0.5727138,
#  0.3417461,
#  0.53372896,
#  0.8536368,
#  0.47752252,
#  0.4252132,
#  0.61015904,
#  0.15567069,
#  0.52408797,
#  0.407038,
#  0.58884746,
#  0.49002138,
#  0.8368432,
#  0.3696858,
#  0.11095705,
#  0.48729768,
#  0.3892589,
#  0.6249876,
#  0.72492135,
#  0.77273095,
#  0.39752427,
#  0.3687585,
#  0.47260675,
#  0.49811,
#  0.408547,
#  0.20958115,
#  0.5241068,
#  0.6943604,
#  0.5911402,
#  0.787302,
#  0.49914485,
#  0.391709,
#  0.5413213,
#  0.36674586,
#  0.3774399,
#  0.57715607,
#  0.05540402,
#  0.46202025,
#  0.57496816,
#  0.8955926,
#  0.5162183,
#  0.72985846,
#  0.40365937,
#  0.58728796,
#  0.9986247,
#  0.51067156,
#  0.46116847,
#  0.4119861,
#  0.61767304,
#  0.78734744,
#  0.3439632,
#  0.65114367,
#  0.3612327,
#  0.38503546,
#  0.3991817,
#  0.611946,
#  0.5119274,
#  0.53504896,
#  0.28288966,
#  0.3125557,
#  0.48465723,
#  0.33172315,
#  0.862768,
#  0.87874246,
#  0.38976538,
#  0.52129877,
#  0.61290276,
#  0.80702466,
#  0.7045235,
#  0.5663164,
#  0.44850564,
#  0.2615127,
#  0.5565332,
#  0.43723884,
#  0.3039952,
#  0.3670656,
#  0.33210555,
#  0.35397893,
#  0.14799634,
#  0.5047123,
#  0.35684177,
#  0.43691242,
#  0.35648414,
#  0.4681713,
#  0.35823327,
#  0.7154464,
#  0.4528641,
#  0.26346883,
#  0.4119546,
#  0.42866066,
#  0.3561114,
#  0.34734702,
#  0.37846,
#  0.3621441,
#  0.49888277,
#  0.9445953,
#  0.39942548,
#  0.36475542,
#  0.55181515,
#  0.83041984,
#  0.40409,
#  0.5119325,
#  0.5817844,
#  0.43105367,
#  0.059223827,
#  0.3744293,
#  0.44870862,
#  0.3818921,
#  0.49480984,
#  0.4059521,
#  0.39836633,
#  0.3945795,
#  0.8878183,
#  0.39692676,
#  0.37322104,
#  0.5915752,
#  0.40206587,
#  0.57423794,
#  0.50929,
#  0.4144645,
#  0.54834723,
#  0.5587893,
#  0.4003316,
#  0.58393395,
#  0.14783092,
#  0.45729423,
#  0.3149088,
#  0.29672563,
#  0.52396935,
#  0.47199923,
#  0.4722742,
#  0.43393603,
#  0.41898778,
#  0.45269883,
#  0.30385238,
#  0.68978596,
#  0.40793246,
#  0.23480937,
#  0.2075993,
#  0.7795151,
#  0.2369726,
#  0.4801823,
#  0.3619715,
#  0.3619715,
#  0.4717259,
#  0.5531713,
#  0.5452099,
#  0.9320927,
#  0.40607414,
#  0.5508759,
#  0.44413212,
#  0.974428,
#  0.94623524,
#  0.37039855,
#  0.32020608,
#  0.48723733,
#  0.26434815,
#  0.35197237,
#  0.4906735,
#  0.28457075,
#  0.5878187,
#  0.29660293,
#  0.31011522,
#  0.17653541,
#  0.3364213,
#  0.3966576,
#  0.43035546,
#  0.5112357,
#  0.5325213,
#  0.7084783,
#  0.6605453,
#  0.48441705,
#  0.26016802,
#  0.71630204,
#  0.30534178,
#  0.32451603,
#  0.32694727,
#  0.46004343,
#  0.33858332,
#  0.113456026,
#  0.47002587,
#  0.55370045,
#  0.3313374,
#  0.3698803,
#  0.5590368,
#  0.6100418,
#  0.40774557,
#  0.53278303,
#  0.13275671,
#  0.64995533,
#  0.5925738,
#  0.52689606,
#  0.5421752,
#  0.293937,
#  0.9876886,
#  0.54465085,
#  0.4626715,
#  0.46341613,
#  0.46036932,
#  0.38937035,
#  0.00046223644,
#  0.30337444,
#  0.40440094,
#  0.33658022,
#  0.5488653,
#  0.4952486,
#  0.40773913,
#  0.42684048,
#  0.4334037,
#  0.37682155,
#  0.99690324,
#  0.5423672,
#  0.511963,
#  0.33749798,
#  0.19628306,
#  0.39311832,
#  0.7703961,
#  0.42268917,
#  0.5018277,
#  0.46581534,
#  0.46188372,
#  0.7398474,
#  0.3688991,
#  0.588867,
#  0.49265102,
#  0.28474456,
#  0.25694796,
#  0.35222748,
#  0.37464467,
#  0.49835405,
#  0.25274417,
#  0.38873687,
#  0.26610982,
#  0.3960099,
#  0.44493577,
#  0.50408983,
#  0.30449283,
#  0.2685367,
#  0.43275172,
#  0.54880965,
#  0.5294173,
#  0.48930168,
#  0.34998322,
#  0.45240846,
#  0.18030892,
#  0.48217082,
#  0.3585052,
#  0.43896076,
#  0.5552056,
#  0.8172884,
#  0.49090368,
#  0.37367126,
#  0.5310671,
#  0.42137766,
#  0.48220152,
#  0.27468485,
#  0.37924087,
#  0.34171343,
#  0.37572804,
#  0.27697793,
#  0.46457788,
#  0.34480304,
#  0.4185344,
#  0.41195294,
#  0.4772004,
#  0.46136042,
#  0.44047382,
#  0.3170902,
#  0.3405582,
#  0.5012941,
#  0.41884103,
#  0.5764627,
#  0.98511446,
#  0.31123182,
#  0.41830453,
#  0.37147322,
#  0.2521355,
#  0.5456523,
#  0.4281524,
#  0.22528917,
#  0.51145816,
#  0.3931245,
#  0.99913764,
#  0.45066053,
#  0.60961163,
#  0.42771292,
#  0.4991698,
#  0.25537264,
#  0.28736383,
#  0.26434815,
#  0.39891425,
#  0.37800285,
#  0.5321844,
#  0.7604475,
#  0.4312169,
#  0.3089685,
#  0.4587735,
#  0.45585343,
#  0.3518233,
#  0.39916268,
#  0.2437555,
#  0.43983635,
#  0.74736,
#  0.5270016,
#  0.42369506,
#  0.22187899,
#  0.2397502,
#  0.38726336,
#  0.39634308,
#  0.35994664,
#  0.52968764,
#  0.3135169,
#  0.38650107,
#  0.7241031,
#  0.18872413,
#  0.31427017,
#  0.29040653,
#  0.38697788,
#  0.37349394,
#  0.64995503,
#  0.66697985,
#  0.6154036,
#  0.407551,
#  0.41392606,
#  0.36281192,
#  0.35202065,
#  0.3515509,
#  0.57160044,
#  0.36039823,
#  0.4904388,
#  0.59694964,
#  0.14930645,
#  0.32803652,
#  0.7433384,
#  0.15822932,
#  0.18956226,
#  0.5624078,
#  0.47549206,
#  0.51378536,
#  0.35139668,
#  0.58166367,
#  0.40817213,
#  0.3278171,
#  0.49942788,
#  0.1515612,
#  0.29738438,
#  0.43016636,
#  0.47717065,
#  0.21487997,
#  0.25818074,
#  0.3574733,
#  0.49618843,
#  0.72727334,
#  0.39716992,
#  0.41392502,
#  0.9843627,
#  0.5192591,
#  0.4345532,
#  0.50051945,
#  0.93206173,
#  0.21839611,
#  0.5402988,
#  0.6326103,
#  0.478665,
#  0.4106573,
#  0.32228422,
#  0.28105274,
#  0.3743098,
#  0.27833515,
#  0.1368311,
#  0.3704,
#  0.19504356,
#  0.5141825,
#  0.46336323,
#  0.5533281,
#  0.5059832,
#  0.5222539,
#  0.47723722,
#  0.30028027,
#  0.30028027,
#  0.32921416,
#  0.45968446,
#  0.5738995,
#  0.2701849,
#  0.50818133,
#  0.4236021,
#  0.35099626,
#  0.49288625,
#  0.2566884,
#  0.41910115,
#  0.57133067,
#  0.29221126,
#  0.8487168,
#  0.26476997,
#  0.2962408,
#  0.44006887,
#  0.6445862,
#  0.35545155,
#  0.41720036,
#  0.31738448,
#  0.46729666,
#  0.016263403,
#  0.42590517,
#  0.27312514,
#  0.26707205,
#  0.38726082,
#  0.83513737,
#  0.44491634,
#  0.46770313,
#  0.22904941,
#  0.525879,
#  0.36756548,
#  0.33398342,
#  0.3274643,
#  0.2734035,
#  0.3467735,
#  0.44432682,
#  0.5712922,
#  0.49241492,
#  0.50731456,
#  0.48630062,
#  0.45363182,
#  0.57492906,
#  0.18945017,
#  0.21038052,
#  0.46957737,
#  0.37187463,
#  0.5102935,
#  0.58330214,
#  0.548913,
#  0.38878515,
#  0.43733585,
#  0.42668733,
#  0.4468308,
#  0.695151,
#  0.9961604,
#  0.4487283,
#  0.35977995,
#  0.3425552,
#  0.62589186,
#  0.87096995,
#  0.9468842,
#  0.2118231,
#  0.3106087,
#  0.34650132,
#  0.6294949,
#  0.44250274,
#  0.7857499,
#  0.4631414,
#  0.42492405,
#  0.42639711,
#  0.5391049,
#  0.45896295,
#  0.19246423,
#  0.33997783,
#  0.11544555,
#  0.52172136,
#  0.27286375,
#  0.35821128,
#  0.3340686,
#  0.45557356,
#  0.43666938,
#  0.423109,
#  0.43844298,
#  0.20122474,
#  0.44171253,
#  0.4407322,
#  0.07774016,
#  0.4377079,
#  0.55023646,
#  0.6452853,
#  0.6160751,
#  0.32144672,
#  0.19915491,
#  0.54625326,
#  0.61020255,
#  0.3711169,
#  0.3916786,
#  0.9969908,
#  0.3471711,
#  0.13644938,
#  0.13362654,
#  0.48868245,
#  0.3775857,
#  0.40309685,
#  0.5527792,
#  0.45148298,
#  0.46767384,
#  0.20697454,
#  0.4567639,
#  0.5912433,
#  0.2597656,
#  0.38451132,
#  0.20554456,
#  0.41393194,
#  0.26690763,
#  0.43133867,
#  0.38368234,
#  0.36273545,
#  0.43527386,
#  0.10715999,
#  0.38561502,
#  0.87204325,
#  0.5194555,
#  0.49985516,
#  0.20945229,
#  0.35410494,
#  0.4020123,
#  0.48644844,
#  0.63653445,
#  0.4803673,
#  0.25482178,
#  0.6126511,
#  0.5785683,
#  0.40305716,
#  0.10287209,
#  0.043714713,
#  0.34171635,
#  0.58274305,
#  0.5464592,
#  0.6184905,
#  0.27839482,
#  0.40335444,
#  0.33298308,
#  0.42484963,
#  0.5700774,
#  0.29683432,
#  0.3815519,
#  0.30993506,
#  0.46196616,
#  0.6335965,
#  0.5267019,
#  0.4999017,
#  0.45669568,
#  0.255357,
#  0.5678511,
#  0.49440223,
#  0.20997581,
#  0.3437879,
#  0.3198583,
#  0.39679998,
#  0.44837153,
#  0.6266732,
#  0.77164704,
#  0.5304838,
#  0.50605243,
#  0.35077986,
#  0.3251103,
#  0.44854528,
#  0.40157953,
#  0.21569628,
#  0.35580346,
#  0.99893147,
#  0.8684253,
#  0.9277269,
#  0.243338,
#  0.7900635,
#  0.6251131,
#  0.97042996,
#  0.37283772,
#  0.42487672,
#  0.45526606,
#  0.20192203,
#  0.5909057,
#  0.7541505,
#  0.37726513,
#  0.29682365,
#  0.503401,
#  0.48849982,
#  0.44301638,
#  0.4847418,
#  0.4724713,
#  0.44244227,
#  0.42137605,
#  0.33251125,
#  0.5886685,
#  0.4074582,
#  0.4472942,
#  0.3147848,
#  0.80573314,
#  0.35777736,
#  0.38163152,
#  0.27259606,
#  0.36795795,
#  0.39794382,
#  0.34684983,
#  0.30184063,
#  0.26827413,
#  0.54082733,
#  0.46176183,
#  0.34677216,
#  0.37876856,
#  0.430219,
#  0.34805134,
#  0.35800946,
#  0.5389774,
#  0.58661795,
#  0.40520582,
#  0.38078755,
#  0.38775367,
#  0.19091336,
#  0.45198306,
#  0.15311348,
#  0.28092137,
#  0.42255825,
#  0.6286504,
#  0.20555031,
#  0.65585715,
#  0.6527106,
#  0.4411954,
#  0.34473598,
#  0.5389444,
#  0.3844658,
#  0.36224422,
#  0.36844152,
#  0.33562604,
#  0.45552814,
#  0.4584919,
#  0.32186326,
#  0.5381456,
#  0.29889792,
#  0.27433226,
#  0.22520304,
#  0.6466341,
#  0.52404326,
#  0.46851808,
#  0.4920171,
#  0.5612066,
#  0.3651578,
#  0.4719972,
#  0.4202215,
#  0.27108335,
#  0.3104288,
#  0.4829319,
#  0.39131656]

# %%
#y_true of each assay
y_true_1 = y_true(1, test_data)
y_true_2 = y_true(2, test_data)
y_true_3 = y_true(3, test_data)
y_true_4 = y_true(4, test_data)
y_true_5 = y_true(5, test_data)
y_true_6 = y_true(6, test_data)
y_true_7 = y_true(7, test_data)
y_true_8 = y_true(8, test_data)
y_true_9 = y_true(9, test_data)
y_true_10 = y_true(10, test_data)
y_true_11 = y_true(11, test_data)
y_true_12 = y_true(12, test_data)

# y_true_3 = [test_data.y[i][2] for i in range(len(test_data.y))]

# %%
#y_pred of each assay
y_pred_1 = y_pred(1, pred_data)
y_pred_2 = y_pred(2, pred_data)
y_pred_3 = y_pred(3, pred_data)
y_pred_4 = y_pred(4, pred_data)
y_pred_5 = y_pred(5, pred_data)
y_pred_6 = y_pred(6, pred_data)
y_pred_7 = y_pred(7, pred_data)
y_pred_8 = y_pred(8, pred_data)
y_pred_9 = y_pred(9, pred_data)
y_pred_10 = y_pred(10, pred_data)
y_pred_11 = y_pred(11, pred_data)
y_pred_12 = y_pred(12, pred_data)

# pred_data_3 = [pred_data[i][3][0] for i in range(len(pred_data))]

# %%
# pred_data_3 = [pred_data[i][2] for i in range(len(pred_data))] #Ask about this
# pred_data_3

# %%
# pred_data_12 = [pred_data[i][11][0] for i in range(len(pred_data))] #Ask about this
# pred_data_12

# %% [markdown]
# ## Evaluating the model

# %%
#Evaluation Metrics

metric = dc.metrics.Metric(dc.metrics.roc_auc_score)
metric1 = dc.metrics.Metric(dc.metrics.balanced_accuracy_score)
metric2 = dc.metrics.Metric(dc.metrics.recall_score)
metric3 = dc.metrics.Metric(dc.metrics.f1_score)
metric4 = dc.metrics.Metric(dc.metrics.precision_score) #doesnt work - use sklearn for this

# %%
smiles2img_model.evaluate(test_data, [metric, metric1, metric2, metric3], transformers)
# Out:
# {'roc_auc_score': 0.544011586438741,
#  'balanced_accuracy_score': 0.5270941495310725,
#  'recall_score': 0.4570439097552119,
#  'f1_score': 0.12720239559751137}

# %% [markdown]
# #### Precision and Recall score

# %%
#Calculating precision and recall score
precision_score_1, recall_score_1, _ = precision_recall_curve(y_true_1,y_pred_1)
precision_score_2, recall_score_2, _ = precision_recall_curve(y_true_2,y_pred_2)
precision_score_3, recall_score_3, _ = precision_recall_curve(y_true_3,y_pred_3)
precision_score_4, recall_score_4, _ = precision_recall_curve(y_true_4,y_pred_4)
precision_score_5, recall_score_5, _ = precision_recall_curve(y_true_5,y_pred_5)
precision_score_6, recall_score_6, _ = precision_recall_curve(y_true_6,y_pred_6)
precision_score_7, recall_score_7, _ = precision_recall_curve(y_true_7,y_pred_7)
precision_score_8, recall_score_8, _ = precision_recall_curve(y_true_8,y_pred_8)
precision_score_9, recall_score_9, _ = precision_recall_curve(y_true_9,y_pred_9)
precision_score_10, recall_score_10, _ = precision_recall_curve(y_true_10,y_pred_10)
precision_score_11, recall_score_11, _ = precision_recall_curve(y_true_11,y_pred_11)
precision_score_12, recall_score_12, _ = precision_recall_curve(y_true_12,y_pred_12)

average_precision_1 = average_precision_score(y_true_1, y_pred_1)                                                                
average_precision_2 = average_precision_score(y_true_2, y_pred_2)
average_precision_3 = average_precision_score(y_true_3, y_pred_3)
average_precision_4 = average_precision_score(y_true_4, y_pred_4)
average_precision_5 = average_precision_score(y_true_5, y_pred_5)
average_precision_6 = average_precision_score(y_true_6, y_pred_6)
average_precision_7 = average_precision_score(y_true_7, y_pred_7)  
average_precision_8 = average_precision_score(y_true_8, y_pred_8)
average_precision_9 = average_precision_score(y_true_9, y_pred_9)
average_precision_10 = average_precision_score(y_true_10, y_pred_10)
average_precision_11 = average_precision_score(y_true_11, y_pred_11)
average_precision_12 = average_precision_score(y_true_12, y_pred_12)

# %%
#Plotting precision-recall curve
fig, ax = plt.subplots(figsize=(10,8))

precision_recall1 = PrecisionRecallDisplay(recall = recall_score_1, precision = precision_score_1, 
                                          average_precision = average_precision_1)
precision_recall2 = PrecisionRecallDisplay(recall = recall_score_2, precision = precision_score_2, 
                                          average_precision = average_precision_2)
precision_recall3 = PrecisionRecallDisplay(recall = recall_score_3, precision = precision_score_3, 
                                          average_precision = average_precision_3)
precision_recall4 = PrecisionRecallDisplay(recall = recall_score_4, precision = precision_score_4, 
                                          average_precision = average_precision_4)
precision_recall5 = PrecisionRecallDisplay(recall = recall_score_5, precision = precision_score_5, 
                                          average_precision = average_precision_5)
precision_recall6 = PrecisionRecallDisplay(recall = recall_score_6, precision = precision_score_6, 
                                          average_precision = average_precision_6)
precision_recall7 = PrecisionRecallDisplay(recall = recall_score_7, precision = precision_score_7, 
                                          average_precision = average_precision_7)
precision_recall8 = PrecisionRecallDisplay(recall = recall_score_8, precision = precision_score_8, 
                                          average_precision = average_precision_8)
precision_recall9 = PrecisionRecallDisplay(recall = recall_score_9, precision = precision_score_9, 
                                          average_precision = average_precision_9)
precision_recall10 = PrecisionRecallDisplay(recall = recall_score_10, precision = precision_score_10, 
                                          average_precision = average_precision_10)
precision_recall11 = PrecisionRecallDisplay(recall = recall_score_11, precision = precision_score_11, 
                                          average_precision = average_precision_11)
precision_recall12 = PrecisionRecallDisplay(recall = recall_score_12, precision = precision_score_12, 
                                          average_precision = average_precision_12)

precision_recall1.plot(ax=ax, label='NR-AR')
precision_recall2.plot(ax=ax, label='NR-AR-LBD')
precision_recall3.plot(ax=ax, label='NR-AhR')
precision_recall4.plot(ax=ax, label='NR-Aromatase')
precision_recall5.plot(ax=ax, label='NR-ER')
precision_recall6.plot(ax=ax, label='NR-ER-LBD')
precision_recall7.plot(ax=ax, label='NR-PPAR-gamma')
precision_recall8.plot(ax=ax, label='SR-ARE')
precision_recall9.plot(ax=ax, label='SR-ATAD5')
precision_recall10.plot(ax=ax, label='SR-HSE')
precision_recall11.plot(ax=ax, label='SR-MMP')
precision_recall12.plot(ax=ax, label='SR-p53')

plt.title('Precision-Recall Curve for 12 assays') #NR-AR
plt.legend(loc='upper right')
#4x3 plot of all 12 assays
#modify axis?
#add average precision?

# %% [markdown]
# ^^Model 4

# %%
# print(f"Model evaluation on train dataset: {smiles2img_model.evaluate(train_data, [metric], transformers)}")
# print(f"Model evaluation on validation dataset: {smiles2img_model.evaluate(valid_data, [metric], transformers)}")
# print(f"Model evaluation on test dataset: {smiles2img_model.evaluate(test_data, [metric], transformers)}")

# %%
# print(f"Model evaluation on train dataset: {smiles2img_model.evaluate(train_data, [metric1], transformers)}")
# print(f"Model evaluation on validation dataset: {smiles2img_model.evaluate(valid_data, [metric1], transformers)}")
# print(f"Model evaluation on test dataset: {smiles2img_model.evaluate(test_data, [metric1], transformers)}")

# %% [markdown]
# ### Balanced Accuracy Score

# %%
#Test

from sklearn.metrics import jaccard_score
from sklearn.metrics import accuracy_score
# from sklearn.metrics import roc_auc 

# acc_1 = jaccard_score(y_true_1, y_pred_1)
acc2 = accuracy_score(y_true_1, y_pred_1)

# smiles2img_model.evaluate(test_data, [metric1], transformers)
#round values in y_pred to convert back to binary values (i.e. round up if more tha 0.5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16216\2102813324.py in <module>
#       6
#       7 # acc_1 = jaccard_score(y_true_1, y_pred_1)
# ----> 8 acc2 = accuracy_score(y_true_1, y_pred_1)
#       9
#      10 # smiles2img_model.evaluate(test_data, [metric1], transformers)
#
# ~\Anaconda3\envs\tdaf-tf2p7\lib\site-packages\sklearn\metrics\_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     209
#     210     # Compute accuracy for each possible representation
# --> 211     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     212     check_consistent_length(y_true, y_pred, sample_weight)
#     213     if y_type.startswith("multilabel"):
#
# ~\Anaconda3\envs\tdaf-tf2p7\lib\site-packages\sklearn\metrics\_classification.py in _check_targets(y_true, y_pred)
#      93         raise ValueError(
#      94             "Classification metrics can't handle a mix of {0} and {1} targets".format(
# ---> 95                 type_true, type_pred
#      96             )
#      97         )
#
# ValueError: Classification metrics can't handle a mix of binary and continuous targets

# %% [markdown]
# ### Splitting datasets with SmilesToImage featuriser

# %%
# # #Testing NN with autoencoder and SmilesToImage featuriser
# tasks, datasets, transformers = dc.molnet.load_tox21(featurizer = dc.feat.SmilesToImage(img_size=100, img_spec='std'),
#     save_dir=r'C:\Users\ym20201\Documents\Datasets',
#     data_dir=r'C:\Users\ym20201\Documents\Datasets')

# splitter = dc.splits.RandomSplitter()
# # featurizer = featurizer

# # datasets = tf.data.Dataset.range(3)

# #Split dataset into train,valid,test datasets
# train_data, valid_data,test_data = splitter.train_valid_test_split(
#     datasets[0], 
#     frac_train = 0.8, frac_valid = 0.08, frac_test = 0.12)

# #Featurisation using SmilesToImage
# train_feat = featurizer.featurize(train_data.ids)
# valid_feat = featurizer.featurize(valid_data.ids)
# test_feat = featurizer.featurize(test_data.ids)

# #train_feat = train_feat.astype('float32')/255
# train_feat = train_feat.astype('object')
# # train_feat = train_feat.reshape((len(train_feat), np.prod(train_feat.shape[1:])))


# # # #Converting numpy array to tensor
# train_tensor = tf.convert_to_tensor(train_feat)
# # # train_feat.info()
# # train_feat = np.array(train_feat, dtype=object)
# # #train_feat = np.asarray(train_feat).astype(np.float32)


# autoencoder.compile(optimizer='adam', loss=losses.MeanSquaredError())
# # autoencoder = dc.models.Autoencoder(img_size=256, img_spec = 'flat')
# autoencoder.fit(train_feat,epochs=10)


# ##Use this to plot featurised 2D data
# # plt.imshow(dataset.X[0], interpolation='nearest')
# #plt.show()

# %%
# # #Testing NN with SmilesToImage featuriser
# tasks, datasets, transformers = dc.molnet.load_tox21(
#     save_dir=r'C:\Users\ym20201\Documents\Datasets',
#     data_dir=r'C:\Users\ym20201\Documents\Datasets')

# splitter = dc.splits.RandomSplitter()
# featurizer = dc.feat.SmilesToImage(img_size=80, img_spec='std')

# # datasets = tf.data.Dataset.range(3)

# #Split dataset into train,valid,test datasets
# train_data, valid_data,test_data = splitter.train_valid_test_split(
#     datasets[0], 
#     frac_train = 0.8, frac_valid = 0.08, frac_test = 0.12)

# #Featurisation using SmilesToImage
# train_feat = featurizer.featurize(train_data.ids)
# valid_feat = featurizer.featurize(valid_data.ids)
# test_feat = featurizer.featurize(test_data.ids)

# # plt.imshow(train_feat[0], interpolation='nearest')
# # plt.show()

# %%
# #Filtering out empty arrays in featurised datasets
# train_feat_new = []
# for i in range(len(train_feat)):
#     if train_feat[i].shape != (0,):
#         train_feat_new.append(train_feat[i])
        
# valid_feat_new = []
# for i in range(len(valid_feat)):
#     if valid_feat[i].shape != (0,):
#         valid_feat_new.append(valid_feat[i])

# test_feat_new = []
# for i in range(len(test_feat)):
#     if test_feat[i].shape != (0,):
#         test_feat_new.append(test_feat[i])

# %%
# #Converting numpy array to tensor
# train_tensor = []
# for i in range(len(train_feat_new)):
#     tensor = tf.convert_to_tensor(train_feat_new[i])
#     train_tensor.append(tensor)
    
# valid_tensor = []
# for i in range(len(valid_feat_new)):
#     tensor_v = tf.convert_to_tensor(valid_feat_new[i])
#     valid_tensor.append(tensor_v)
    
# test_tensor = []
# for i in range(len(test_feat_new)):
#     tensor_t = tf.convert_to_tensor(test_feat_new[i])
#     test_tensor.append(tensor_t)

# %%
# plt.savefig('smilestoimg example')

# %%
# Chem.MolFromSmiles(train_data.ids[1])

# %%
# plt.imshow(train_feat_conv[2], interpolation='nearest')

# %%
len(train_data.X[2])
# Out:
# 80

# %% [markdown]
# ### Autoencoder with 2D convolutional layer

# %%
layers.Conv2D

# %%
# #New autoencoder
# # This is the size of our encoded representations
# encoding_dim = 32  # 32 floats -> compression of factor 24.5, assuming the input is 784 floats

# #add pooling layers 

# # input_shape = (4, 28, 28, 3)
# # x = tf.random.normal(input_shape)

# input_img = layers.Conv2D(filters=32, kernel_size=3, activation='relu', dilation_rate=2, input_shape=(40,40,1))
# # "encoded" is the encoded representation of the input
# encoded = layers.Dense(encoding_dim, activation='relu')(input_img)
# # "decoded" is the lossy reconstruction of the input
# decoded = layers.Dense(784, activation='sigmoid')(encoded)

# # This model maps an input to its reconstruction
# autoencoder = keras.Model(input_img, decoded)

# # This model maps an input to its encoded representation
# encoder = keras.Model(input_img, encoded)

# # This is our encoded (32-dimensional) input
# encoded_input = keras.Input(shape=(encoding_dim,))
# # Retrieve the last layer of the autoencoder model
# decoder_layer = autoencoder.layers[-1]
# # Create the decoder model
# decoder = keras.Model(encoded_input, decoder_layer(encoded_input))

# %%
# #Autoencoder Test 2

# encoder_input = layers.Input(shape=(40,40,1))
# input_img = layers.Conv2D(filters=32,
#                           kernel_size=3,
#                           activation='relu',
#                           dilation_rate=2)(encoder_input)
# encoded = layers.Dense(64, activation='relu')(input_img)
# encoder = keras.Model(encoder_input, encoded)

# # Create the decoder
# decoder_input = layers.Input(shape=(64,))
# decoded = layers.Dense(784, activation='sigmoid')(decoder_input)
# decoder = keras.Model(decoder_input, decoded)

# # Create the autoencoder
# autoencoder = keras.Model(encoder_input, decoder(encoder(encoder_input)))

# %%
#New autoencoder - modified
#Simple convolutional autoencoder
# This is the size of our encoded representations
encoding_dim = 32  # 32 floats -> compression of factor 24.5, assuming the input is 784 floats

#add pooling layers 

input_img = layers.Input(shape=(40,40,1))
Conv2d_1 = layers.Conv2D(filters=32,
                          kernel_size=3,
                          activation='relu',
                          dilation_rate=2)(input_img)

#add pooling layer
#add flatten layer before dense

# "encoded" is the encoded representation of the input
encoded = layers.Dense(encoding_dim, activation='relu')(Conv2d_1)

# "decoded" is the lossy reconstruction of the input
decoded = layers.Dense(784, activation='relu')(encoded)

# This model maps an input to its reconstruction
autoencoder = keras.Model(input_img, decoded)

# This model maps an input to its encoded representation
encoder = keras.Model(input_img, encoded)

# This is our encoded (32-dimensional) input
encoded_input = keras.Input(shape=(encoding_dim,))

# Retrieve the last layer of the autoencoder model
decoder_layer = autoencoder.layers[-1]

# Create the decoder model
decoder = keras.Model(encoded_input, decoder_layer(encoded_input))

# %%
#Adding more layers- Convolutional autoencoder

# This is the size of our encoded representations
encoding_dim = 32  # 32 floats -> compression of factor 24.5, assuming the input is 784 floats

#add pooling layers 

input_img = layers.Input(shape=(40,40,1))
Conv2D_1 = layers.Conv2D(filters=32,
                          kernel_size=3,
                          activation='relu',
                          dilation_rate=2)(input_img)

MaxPool2D_1 = layers.MaxPooling2D((2, 2), padding='same')(Conv2D_1)
Conv2D_2 = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(MaxPool2D_1)
MaxPool2D_2 = layers.MaxPooling2D((2, 2), padding='same')(Conv2D_2)
Flatten = layers.Flatten()(MaxPool2D_2)
encoded = layers.Dense(encoding_dim, activation='relu')(Flatten)

# "encoded" is the encoded representation of the input
# encoded = layers.Dense(encoding_dim, activation='relu')(input)
# encoded = layers.MaxPooling2D(pool_size=(2,2), padding='same')(encoded)
# encoded = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(encoded)
# x = layers.Dense(encoding_dim, activation='relu')(x)
# x = layers.MaxPooling2D(pool_size=(2,2), padding='same')(x)
# x = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(x)
# encoded = layers.MaxPooling2D(pool_size=(2,2), padding='same')(x)


# "decoded" is the lossy reconstruction of the input
decoded = layers.Dense(784, activation='relu')(encoded)

# This model maps an input to its reconstruction
autoencoder = keras.Model(input_img, decoded)

# This model maps an input to its encoded representation
encoder = keras.Model(input_img, encoded)

# This is our encoded (32-dimensional) input
encoded_input = keras.Input(shape=(encoding_dim,))

# Retrieve the last layer of the autoencoder model
decoder_layer = autoencoder.layers[-1]

# Create the decoder model
decoder = keras.Model(encoded_input, decoder_layer(encoded_input))

# %%
# # From keras blog
# input_img = layers.Input(shape=(80, 80, 1))

# Conv2D_1 = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(input_img)
# x = layers.MaxPooling2D((2, 2), padding='same')(Conv2D_1)
# x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
# x = layers.MaxPooling2D((2, 2), padding='same')(x)
# x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
# encoded = layers.MaxPooling2D((2, 2), padding='same')(x)

# # at this point the representation is (4, 4, 8) i.e. 128-dimensional

# x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(encoded)
# x = layers.UpSampling2D((2, 2))(x)
# x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
# x = layers.UpSampling2D((2, 2))(x)
# x = layers.Conv2D(16, (3, 3), activation='relu')(x)
# x = layers.UpSampling2D((2, 2))(x)
# decoded = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)


# # This model maps an input to its reconstruction
# autoencoder = keras.Model(input_img, decoded)

# %%
#Compile autoencoder
autoencoder.compile(optimizer='adam', loss='mean_squared_error')
autoencoder.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 40, 40, 1)]       0
#
#  conv2d_1 (Conv2D)           (None, 36, 36, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 18, 18, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 18, 18, 16)        4624
#
#  max_pooling2d_1 (MaxPooling  (None, 9, 9, 16)         0
#  2D)
#
#  flatten (Flatten)           (None, 1296)              0
#
#  dense_2 (Dense)             (None, 32)                41504
#
#  dense_3 (Dense)             (None, 784)               25872
#
# =================================================================
# Total params: 72,320
# Trainable params: 72,320
# Non-trainable params: 0
# _________________________________________________________________

# %%
print(train_tensor[0].shape)
# Out:
# (80, 80, 1)

# %%
print(train_tensor[10].shape)
print(len(train_tensor))
print(valid_tensor[10].shape)
print(len(valid_tensor))
# Out:
# (80, 80, 1)
# 4984
# (80, 80, 1)
# 498

# %%
#Training the autoencoder
autoencoder_test = autoencoder.fit(x=train_tensor,
                                   y=train_tensor,
                                   epochs=10,
                                   batch_size=512,
                                   shuffle=True,
                                  validation_data=(valid_tensor, valid_tensor))
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18476\4227774747.py in <module>
#       5                                    batch_size=512,
#       6                                    shuffle=True,
# ----> 7                                   validation_data=(valid_tensor, valid_tensor))
#       8
#
# ~\Anaconda3\envs\tdaf-tf2p7\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~\Anaconda3\envs\tdaf-tf2p7\lib\site-packages\tensorflow\python\framework\func_graph.py in autograph_handler(*args, **kwargs)
#    1127           except Exception as e:  # pylint:disable=broad-except
#    1128             if hasattr(e, "ag_error_metadata"):
# -> 1129               raise e.ag_error_metadata.to_exception(e)
#    1130             else:
#    1131               raise
#
# ValueError: in user code:
#
#     File "C:\Users\ym20201\Anaconda3\envs\tdaf-tf2p7\lib\site-packages\keras\engine\training.py", line 878, in train_function  *
#         return step_function(self, iterator)
#     File "C:\Users\ym20201\Anaconda3\envs\tdaf-tf2p7\lib\site-packages\keras\engine\training.py", line 867, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\ym20201\Anaconda3\envs\tdaf-tf2p7\lib\site-packages\keras\engine\training.py", line 860, in run_step  **
#         outputs = model.train_step(data)
#     File "C:\Users\ym20201\Anaconda3\envs\tdaf-tf2p7\lib\site-packages\keras\engine\training.py", line 808, in train_step
#         y_pred = self(x, training=True)
#     File "C:\Users\ym20201\Anaconda3\envs\tdaf-tf2p7\lib\site-packages\keras\utils\traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "C:\Users\ym20201\Anaconda3\envs\tdaf-tf2p7\lib\site-packages\keras\engine\input_spec.py", line 199, in assert_input_compatibility
#         raise ValueError(f'Layer "{layer_name}" expects {len(input_spec)} input(s),'
#
#     ValueError: Layer "model" expects 1 input(s), but it received 4985 input tensors. Inputs received: [<tf.Tensor 'IteratorGetNext:0' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:1' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:2' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:3' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:4' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:5' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:6' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:7' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:8' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:9' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:10' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:11' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:12' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:13' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:14' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:15' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:16' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:17' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:18' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:19' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:20' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:21' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:22' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:23' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:24' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:25' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:26' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:27' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:28' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:29' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:30' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:31' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:32' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:33' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:34' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:35' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:36' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:37' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:38' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:39' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:40' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:41' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:42' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:43' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:44' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:45' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:46' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:47' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:48' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:49' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:50' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:51' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:52' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:53' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:54' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:55' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:56' shape=(None, 80, 1) dtype=float64>, <tf.Tensor 'IteratorGetNext:57 ...

# %%
# tasks, datasets, transformers = dc.molnet.load_tox21()
# train_data, valid_data, test_data = datasets

# featurizer = dc.feat.Smiles2Img(img_size=256, img_spec='flat')
# train_feat = featurizer.featurise(train_data.X)
# ...

# autoencoder = dc.models.Autoencoder(img_size=256, img_spec = 'flat')
# autoencoder.fit(train_feat)

# metrics = dc.metrics
# train_scores = autoencoder.evaluate(train_feat, [metric])
