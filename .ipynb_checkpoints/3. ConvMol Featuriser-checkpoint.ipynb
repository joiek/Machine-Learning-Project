# %% [markdown]
# ## 3. ConvMol Featuriser

# %%
#Import Statements
import deepchem as dc
from rdkit import Chem
from rdkit.Chem import Draw
import tensorflow as tf

import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

from sklearn import metrics
from sklearn.metrics import f1_score
from sklearn.metrics import (precision_recall_curve, average_precision_score, PrecisionRecallDisplay)
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import roc_auc_score
# Out:
# 2023-04-10 21:59:12.549872: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Loading Tox21 dataset using ConvMol Featuriser

# %%
#ConvMol featuriser
tasks, datasets, transformers = dc.molnet.load_tox21(
    featurizer = dc.feat.ConvMolFeaturizer(),
    save_dir=r'C:\Users\ym20201\Documents\Datasets',
    data_dir=r'C:\Users\ym20201\Documents\Datasets')

splitter = dc.splits.RandomSplitter()

train_data, valid_data,test_data = datasets
# Out:
# [21:59:26] WARNING: not removing hydrogen atom without neighbors
# [22:01:16] WARNING: not removing hydrogen atom without neighbors

# %% [markdown]
# ## Graph Convolutional Model

# %%
#Model 1
convmol_model1 = dc.models.GraphConvModel(
    n_tasks = len(tasks),
    graph_conv_layers=[64,64], #default value
    dense_layer_size=128,
    dropout=0.0,
    mode='classification',
    number_atom_features=75,#default value
    batch_normalize=True,
    uncertainty=False,
    n_classes=12,
    learning_rate=0.01,
    batch_size=100)

# %%
#Model 2
convmol_model2 = dc.models.GraphConvModel(
    n_tasks = len(tasks),
    graph_conv_layers=[32,32],
    dense_layer_size=128,
    dropout=0.0,
    mode='classification',
    number_atom_features=75,
    batch_normalize=True,
    uncertainty=False,
    n_classes=12,
    learning_rate=0.01,
    batch_size=100)

# %%
#Model 3
convmol_model3 = dc.models.GraphConvModel(
    n_tasks = len(tasks),
    graph_conv_layers=[32,32],
    dense_layer_size=128,
    dropout=0.2,
    mode='classification',
    number_atom_features=75,
    batch_normalize=True,
    uncertainty=False,
    n_classes=12,
    learning_rate=0.01,
    batch_size=100)

# %%
#Model 4
convmol_model4 = dc.models.GraphConvModel(
    n_tasks = len(tasks),
    graph_conv_layers=[64,32],
    dense_layer_size=250,
    dropout=0.0,
    mode='classification',
    number_atom_features=75,
    batch_normalize=True,
    uncertainty=False,
    n_classes=12,
    learning_rate=0.01,
    batch_size=100)

# %%
#Model 5
convmol_model5 = dc.models.GraphConvModel(
    n_tasks = len(tasks),
    graph_conv_layers=[64,32,32],
    dense_layer_size=250,
    dropout=0.0,
    mode='classification',
    number_atom_features=75,
    batch_normalize=True,
    uncertainty=False,
    n_classes=12,
    learning_rate=0.01,
    batch_size=100)

# %%
#Model 6
convmol_model6 = dc.models.GraphConvModel(
    n_tasks = len(tasks),
    graph_conv_layers=[32,32,32],
    dense_layer_size=128,
    dropout=0.0,
    mode='classification',
    number_atom_features=75,#default value
    batch_normalize=True,
    uncertainty=False,
    n_classes=12,
    learning_rate=0.01,
    batch_size=100)

# %%
#Model 7
convmol_model7 = dc.models.GraphConvModel(
    n_tasks = len(tasks),
    graph_conv_layers=[64,32,16],
    dense_layer_size=128,
    dropout=0.0,
    mode='classification',
    number_atom_features=75,#default value
    batch_normalize=True,
    uncertainty=False,
    n_classes=12,
    learning_rate=0.01,
    batch_size=100)

# %% [markdown]
# The models were fitted and their performance metrics were compared. The 3 best performing models were observed to be models 2, 4 and 6.

# %%
# Best performing models - 2, 4, 6
convmol_model2.fit(
    train_data,
    nb_epoch=10)

convmol_model4.fit(
    train_data,
    nb_epoch=10)

convmol_model6.fit(
    train_data,
    nb_epoch=10)
# Out:
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_27/Reshape_14:0", shape=(495,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_27/Reshape_13:0", shape=(495, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_27/Cast_4:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_27/Reshape_17:0", shape=(1426,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_27/Reshape_16:0", shape=(1426, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_27/Cast_5:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_27/Reshape_20:0", shape=(1305,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_27/Reshape_19:0", shape=(1305, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_27/Cast_6:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_27/Reshape_23:0", shape=(248,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_27/Reshape_22:0", shape=(248, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_27/Cast_7:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Reshape_11:0", shape=(495,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Reshape_10:0", shape=(495, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Reshape_13:0", shape=(1426,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Reshape_12:0", shape=(1426, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Cast_1:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Reshape_15:0", shape=(1305,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Reshape_14:0", shape=(1305, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Cast_2:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Reshape_17:0", shape=(248,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Reshape_16:0", shape=(248, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Cast_3:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Reshape_19:0", shape=(0,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Reshape_18:0", shape=(0, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Cast_4:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Reshape_21:0", shape=(0,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Reshape_20:0", shape=(0, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Cast_5:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Reshape_23:0", shape=(0,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Reshape_22:0", shape=(0, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Cast_6:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Reshape_25:0", shape=(0,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Reshape_24:0", shape=(0, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Cast_7:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Reshape_27:0", shape=(0,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Reshape_26:0", shape=(0, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Cast_8:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Reshape_29:0", shape=(0,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Reshape_28:0", shape=(0, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Cast_9:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_26/Reshape_14:0", shape=(495,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_26/Reshape_13:0", shape=(495, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_26/Cast_4:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_26/Reshape_17:0", shape=(1426,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_26/Reshape_16:0", shape=(1426, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_26/Cast_5:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_26/Reshape_20:0", shape=(1305,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_26/Reshape_19:0", shape=(1305, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_26/Cast_6:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_26/Reshape_23:0", shape=(248,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_26/Reshape_22:0", shape=(248, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_26/Cast_7:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_27/Reshape_14:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_27/Reshape_13:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_27/Cast_4:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_27/Reshape_17:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_27/Reshape_16:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_27/Cast_5:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_27/Reshape_20:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_27/Reshape_19:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_27/Cast_6:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_27/Reshape_23:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_27/Reshape_22:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_27/Cast_7:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Reshape_11:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Reshape_10:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Reshape_13:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Reshape_12:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Cast_1:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Reshape_15:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Reshape_14:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Cast_2:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Reshape_17:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Reshape_16:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Cast_3:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_26/Reshape_14:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_26/Reshape_13:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_26/Cast_4:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_26/Reshape_17:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_26/Reshape_16:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_26/Cast_5:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_26/Reshape_20:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_26/Reshape_19:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_26/Cast_6:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_26/Reshape_23:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_26/Reshape_22:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_26/Cast_7:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_27/Reshape_26:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_27/Reshape_25:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_27/Cast_8:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_27/Reshape_29:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_27/Reshape_28:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_27/Cast_9:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Reshape_21:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Reshape_20:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Cast_5:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_26/Reshape_26:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_26/Reshape_25:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_26/Cast_8:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_26/Reshape_29:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_26/Reshape_28:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_26/Cast_9:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_27/Reshape_32:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_27/Reshape_31:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_27/Cast_10:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_27/Reshape_35:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_27/Reshape_34:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_27/Cast_11:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Reshape_19:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Reshape_18:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_conv_27/Cast_4:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_26/Reshape_32:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_26/Reshape_31:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_26/Cast_10:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_26/Reshape_35:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_26/Reshape_34:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_11/graph_pool_26/Cast_11:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_29/Reshape_14:0", shape=(417,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_29/Reshape_13:0", shape=(417, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_29/Cast_4:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_29/Reshape_17:0", shape=(1348,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_29/Reshape_16:0", shape=(1348, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_29/Cast_5:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_29/Reshape_20:0", shape=(1185,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_29/Reshape_19:0", shape=(1185, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_29/Cast_6:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_29/Reshape_23:0", shape=(184,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_29/Reshape_22:0", shape=(184, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_29/Cast_7:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_conv_29/Reshape_11:0", shape=(417,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_conv_29/Reshape_10:0", shape=(417, 64), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_conv_29/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_conv_29/Reshape_13:0", shape=(1348,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_conv_29/Reshape_12:0", shape=(1348, 64), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_conv_29/Cast_1:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_conv_29/Reshape_15:0", shape=(1185,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_conv_29/Reshape_14:0", shape=(1185, 64), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_conv_29/Cast_2:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_conv_29/Reshape_17:0", shape=(184,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_conv_29/Reshape_16:0", shape=(184, 64), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_conv_29/Cast_3:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_conv_29/Reshape_19:0", shape=(0,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_conv_29/Reshape_18:0", shape=(0, 64), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_conv_29/Cast_4:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_conv_29/Reshape_21:0", shape=(0,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_conv_29/Reshape_20:0", shape=(0, 64), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_conv_29/Cast_5:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_conv_29/Reshape_23:0", shape=(0,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_conv_29/Reshape_22:0", shape=(0, 64), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_conv_29/Cast_6:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_conv_29/Reshape_25:0", shape=(0,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_conv_29/Reshape_24:0", shape=(0, 64), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_conv_29/Cast_7:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_conv_29/Reshape_27:0", shape=(0,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_conv_29/Reshape_26:0", shape=(0, 64), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_conv_29/Cast_8:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_conv_29/Reshape_29:0", shape=(0,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_conv_29/Reshape_28:0", shape=(0, 64), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_conv_29/Cast_9:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_28/Reshape_14:0", shape=(417,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_28/Reshape_13:0", shape=(417, 64), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_28/Cast_4:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_28/Reshape_17:0", shape=(1348,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_28/Reshape_16:0", shape=(1348, 64), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_28/Cast_5:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_28/Reshape_20:0", shape=(1185,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_28/Reshape_19:0", shape=(1185, 64), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_28/Cast_6:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_28/Reshape_23:0", shape=(184,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_28/Reshape_22:0", shape=(184, 64), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_28/Cast_7:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_29/Reshape_14:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_29/Reshape_13:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_29/Cast_4:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_29/Reshape_17:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_29/Reshape_16:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_29/Cast_5:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_29/Reshape_20:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_29/Reshape_19:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_29/Cast_6:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_29/Reshape_23:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_29/Reshape_22:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_29/Cast_7:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_conv_29/Reshape_11:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_conv_29/Reshape_10:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_conv_29/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_conv_29/Reshape_13:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_conv_29/Reshape_12:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_conv_29/Cast_1:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_conv_29/Reshape_15:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_conv_29/Reshape_14:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_conv_29/Cast_2:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_conv_29/Reshape_17:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_conv_29/Reshape_16:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_conv_29/Cast_3:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_28/Reshape_14:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_28/Reshape_13:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_28/Cast_4:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_28/Reshape_17:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_28/Reshape_16:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_28/Cast_5:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_28/Reshape_20:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_28/Reshape_19:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_28/Cast_6:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_28/Reshape_23:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_28/Reshape_22:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_28/Cast_7:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_29/Reshape_26:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_29/Reshape_25:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_29/Cast_8:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_29/Reshape_29:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_29/Reshape_28:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_29/Cast_9:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_conv_29/Reshape_21:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_conv_29/Reshape_20:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_conv_29/Cast_5:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_28/Reshape_26:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_28/Reshape_25:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_28/Cast_8:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_28/Reshape_29:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_28/Reshape_28:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_28/Cast_9:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_29/Reshape_32:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_29/Reshape_31:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_29/Cast_10:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_29/Reshape_35:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_29/Reshape_34:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_12/graph_pool_29/Cast_11:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# ...
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_31/Reshape_23:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_31/Reshape_22:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_31/Cast_7:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_conv_31/Reshape_11:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_conv_31/Reshape_10:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_conv_31/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_conv_31/Reshape_13:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_conv_31/Reshape_12:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_conv_31/Cast_1:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_conv_31/Reshape_15:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_conv_31/Reshape_14:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_conv_31/Cast_2:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_conv_31/Reshape_17:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_conv_31/Reshape_16:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_conv_31/Cast_3:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_30/Reshape_14:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_30/Reshape_13:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_30/Cast_4:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_30/Reshape_17:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_30/Reshape_16:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_30/Cast_5:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_30/Reshape_20:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_30/Reshape_19:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_30/Cast_6:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_30/Reshape_23:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_30/Reshape_22:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_30/Cast_7:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_32/Reshape_26:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_32/Reshape_25:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_32/Cast_8:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_32/Reshape_29:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_32/Reshape_28:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_32/Cast_9:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_conv_32/Reshape_21:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_conv_32/Reshape_20:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_conv_32/Cast_5:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_31/Reshape_26:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_31/Reshape_25:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_31/Cast_8:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_31/Reshape_29:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_31/Reshape_28:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_31/Cast_9:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_conv_31/Reshape_21:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_conv_31/Reshape_20:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_conv_31/Cast_5:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_30/Reshape_26:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_30/Reshape_25:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_30/Cast_8:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_30/Reshape_29:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_30/Reshape_28:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_30/Cast_9:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_32/Reshape_32:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_32/Reshape_31:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_32/Cast_10:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_32/Reshape_35:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_32/Reshape_34:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_32/Cast_11:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_conv_32/Reshape_19:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_conv_32/Reshape_18:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_conv_32/Cast_4:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_31/Reshape_32:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_31/Reshape_31:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_31/Cast_10:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_31/Reshape_35:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_31/Reshape_34:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_31/Cast_11:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_conv_31/Reshape_19:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_conv_31/Reshape_18:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_conv_31/Cast_4:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_30/Reshape_32:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_30/Reshape_31:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_30/Cast_10:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /Users/Joie/.local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_30/Reshape_35:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_30/Reshape_34:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_13/graph_pool_30/Cast_11:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# 0.8558746973673502

# %%
#Evaluation metrics
metric = dc.metrics.Metric(dc.metrics.balanced_accuracy_score)
metric1 = dc.metrics.Metric(dc.metrics.recall_score)
metric2 = dc.metrics.Metric(dc.metrics.f1_score)

convmol_model6.evaluate(test_data, [metric,metric1,metric2], transformers)
# Out:
# {'balanced_accuracy_score': 0.6055584547490797,
#  'recall_score': 0.8171593933266145,
#  'f1_score': 0.1667523778698694}

# %%
#Using models for predictions
m2_gc_pred = convmol_model2.predict(test_data)
m4_gc_pred = convmol_model4.predict(test_data)
m6_gc_pred = convmol_model6.predict(test_data)

# %%
#Function for accessing y_true of each assay
def y_true(assay_num, test_data):
    y_true = []
    for i in range(len(test_data.y)):
        y_true.append(test_data.y[i][assay_num - 1])
        
    return y_true

#Function for accessing y_pred for each assay
def y_pred(assay_num, pred_data):
    y_pred = []
    for i in range(len(pred_data)):
        y_pred.append( pred_data[i][assay_num - 1][0])

    return y_pred

# %%
#y_true of each assay
y_true_1 = y_true(1, test_data)
y_true_2 = y_true(2, test_data)
y_true_3 = y_true(3, test_data)
y_true_4 = y_true(4, test_data)
y_true_5 = y_true(5, test_data)
y_true_6 = y_true(6, test_data)
y_true_7 = y_true(7, test_data)
y_true_8 = y_true(8, test_data)
y_true_9 = y_true(9, test_data)
y_true_10 = y_true(10, test_data)
y_true_11 = y_true(11, test_data)
y_true_12 = y_true(12, test_data)

y_true = [y_true_1, y_true_2, y_true_3, y_true_4, y_true_5, 
        y_true_6, y_true_7, y_true_8, y_true_9, y_true_10,
        y_true_11, y_true_12]

# %% [markdown]
# ### Model 2 - y_pred

# %%
#y_pred of each assay
m2_y_pred_1 = y_pred(1, m2_gc_pred)
m2_y_pred_2 = y_pred(2, m2_gc_pred)
m2_y_pred_3 = y_pred(3, m2_gc_pred)
m2_y_pred_4 = y_pred(4, m2_gc_pred)
m2_y_pred_5 = y_pred(5, m2_gc_pred)
m2_y_pred_6 = y_pred(6, m2_gc_pred)
m2_y_pred_7 = y_pred(7, m2_gc_pred)
m2_y_pred_8 = y_pred(8, m2_gc_pred)
m2_y_pred_9 = y_pred(9, m2_gc_pred)
m2_y_pred_10 = y_pred(10, m2_gc_pred)
m2_y_pred_11 = y_pred(11, m2_gc_pred)
m2_y_pred_12 = y_pred(12, m2_gc_pred)

# %%
def round_pred(y_pred):
    y_pred_new = []
    for i in range(len(y_pred)):
        if y_pred[i] < 0.5:
            new = 0
        else:
            new = 1
        y_pred_new.append(new)
    return y_pred_new

# %%
#Rounding predicted probabilities to binary values
m2_y_pred_new_1 = round_pred(m2_y_pred_1)
m2_y_pred_new_2 = round_pred(m2_y_pred_2)
m2_y_pred_new_3 = round_pred(m2_y_pred_3)
m2_y_pred_new_4 = round_pred(m2_y_pred_4)
m2_y_pred_new_5 = round_pred(m2_y_pred_5)
m2_y_pred_new_6 = round_pred(m2_y_pred_6)
m2_y_pred_new_7= round_pred(m2_y_pred_7)
m2_y_pred_new_8 = round_pred(m2_y_pred_8)
m2_y_pred_new_9 = round_pred(m2_y_pred_9)
m2_y_pred_new_10 = round_pred(m2_y_pred_10)
m2_y_pred_new_11 = round_pred(m2_y_pred_11)
m2_y_pred_new_12 = round_pred(m2_y_pred_12)

# %%
m2_y_pred = [m2_y_pred_1, m2_y_pred_2, m2_y_pred_3, m2_y_pred_4, m2_y_pred_5, 
             m2_y_pred_6, m2_y_pred_7, m2_y_pred_8, m2_y_pred_9, m2_y_pred_10,
            m2_y_pred_11, m2_y_pred_12]

m2_y_pred_new = [m2_y_pred_new_1, m2_y_pred_new_2, m2_y_pred_new_3, m2_y_pred_new_4, m2_y_pred_new_5, 
             m2_y_pred_new_6, m2_y_pred_new_7, m2_y_pred_new_8, m2_y_pred_new_9, m2_y_pred_new_10,
            m2_y_pred_new_11, m2_y_pred_new_12]

# %% [markdown]
# ### Model 4 - y_pred

# %%
#y_pred of each assay
m4_y_pred_1 = y_pred(1, m4_gc_pred)
m4_y_pred_2 = y_pred(2, m4_gc_pred)
m4_y_pred_3 = y_pred(3, m4_gc_pred)
m4_y_pred_4 = y_pred(4, m4_gc_pred)
m4_y_pred_5 = y_pred(5, m4_gc_pred)
m4_y_pred_6 = y_pred(6, m4_gc_pred)
m4_y_pred_7 = y_pred(7, m4_gc_pred)
m4_y_pred_8 = y_pred(8, m4_gc_pred)
m4_y_pred_9 = y_pred(9, m4_gc_pred)
m4_y_pred_10 = y_pred(10, m4_gc_pred)
m4_y_pred_11 = y_pred(11, m4_gc_pred)
m4_y_pred_12 = y_pred(12, m4_gc_pred)

# %%
#Rounding predicted probabilities to binary values
m4_y_pred_new_1 = round_pred(m4_y_pred_1)
m4_y_pred_new_2 = round_pred(m4_y_pred_2)
m4_y_pred_new_3 = round_pred(m4_y_pred_3)
m4_y_pred_new_4 = round_pred(m4_y_pred_4)
m4_y_pred_new_5 = round_pred(m4_y_pred_5)
m4_y_pred_new_6 = round_pred(m4_y_pred_6)
m4_y_pred_new_7= round_pred(m4_y_pred_7)
m4_y_pred_new_8 = round_pred(m4_y_pred_8)
m4_y_pred_new_9 = round_pred(m4_y_pred_9)
m4_y_pred_new_10 = round_pred(m4_y_pred_10)
m4_y_pred_new_11 = round_pred(m4_y_pred_11)
m4_y_pred_new_12 = round_pred(m4_y_pred_12)

# %%
m4_y_pred = [m4_y_pred_1, m4_y_pred_2, m4_y_pred_3, m4_y_pred_4, m4_y_pred_5, 
             m4_y_pred_6, m4_y_pred_7, m4_y_pred_8, m4_y_pred_9, m4_y_pred_10,
            m4_y_pred_11, m4_y_pred_12]

m4_y_pred_new = [m4_y_pred_new_1, m4_y_pred_new_2, m4_y_pred_new_3, m4_y_pred_new_4, m4_y_pred_new_5, 
             m4_y_pred_new_6, m4_y_pred_new_7, m4_y_pred_new_8, m4_y_pred_new_9, m4_y_pred_new_10,
            m4_y_pred_new_11, m4_y_pred_new_12]

# %% [markdown]
# ### Model 6 - y_pred

# %%
#y_pred of each assay
m6_y_pred_1 = y_pred(1, m6_gc_pred)
m6_y_pred_2 = y_pred(2, m6_gc_pred)
m6_y_pred_3 = y_pred(3, m6_gc_pred)
m6_y_pred_4 = y_pred(4, m6_gc_pred)
m6_y_pred_5 = y_pred(5, m6_gc_pred)
m6_y_pred_6 = y_pred(6, m6_gc_pred)
m6_y_pred_7 = y_pred(7, m6_gc_pred)
m6_y_pred_8 = y_pred(8, m6_gc_pred)
m6_y_pred_9 = y_pred(9, m6_gc_pred)
m6_y_pred_10 = y_pred(10, m6_gc_pred)
m6_y_pred_11 = y_pred(11, m6_gc_pred)
m6_y_pred_12 = y_pred(12, m6_gc_pred)

# %%
#Rounding predicted probabilities to binary values
m6_y_pred_new_1 = round_pred(m6_y_pred_1)
m6_y_pred_new_2 = round_pred(m6_y_pred_2)
m6_y_pred_new_3 = round_pred(m6_y_pred_3)
m6_y_pred_new_4 = round_pred(m6_y_pred_4)
m6_y_pred_new_5 = round_pred(m6_y_pred_5)
m6_y_pred_new_6 = round_pred(m6_y_pred_6)
m6_y_pred_new_7= round_pred(m6_y_pred_7)
m6_y_pred_new_8 = round_pred(m6_y_pred_8)
m6_y_pred_new_9 = round_pred(m6_y_pred_9)
m6_y_pred_new_10 = round_pred(m6_y_pred_10)
m6_y_pred_new_11 = round_pred(m6_y_pred_11)
m6_y_pred_new_12 = round_pred(m6_y_pred_12)

# %%
m6_y_pred = [m6_y_pred_1, m6_y_pred_2, m6_y_pred_3, m6_y_pred_4, m6_y_pred_5, 
             m6_y_pred_6, m6_y_pred_7, m6_y_pred_8, m6_y_pred_9, m6_y_pred_10,
            m6_y_pred_11, m6_y_pred_12]

m6_y_pred_new = [m6_y_pred_new_1, m6_y_pred_new_2, m6_y_pred_new_3, m6_y_pred_new_4, m6_y_pred_new_5, 
             m6_y_pred_new_6, m6_y_pred_new_7, m6_y_pred_new_8, m6_y_pred_new_9, m6_y_pred_new_10,
            m6_y_pred_new_11, m6_y_pred_new_12]

# %% [markdown]
# ## Evaluating the model
# ### Precision and Recall score

# %%
#Function to ouput precision and recall score
def precision_recall_score(y_true, y_pred):
    precision_score = []
    recall_score = []
    for i in range(len(y_true)):
        precision, recall, _ = precision_recall_curve(y_true[i], y_pred[i])
        
        precision_score.append(precision)
        recall_score.append(recall)
    
    return precision_score, recall_score

# %%
def PrecisionRecallPlot(precision, recall, assays):
    precision_recall = []
    for i in range(len(precision)):
        plot = PrecisionRecallDisplay(recall = recall[i], precision = precision[i])
        precision_recall.append(plot)
        
    for i in range(len(precision_recall)):
        precision_recall[i].plot(ax=ax, label=assays[i])

# %%
m2_precision_score, m2_recall_score = precision_recall_score(y_true, m2_y_pred)
m4_precision_score, m4_recall_score = precision_recall_score(y_true, m4_y_pred)
m6_precision_score, m6_recall_score = precision_recall_score(y_true, m6_y_pred)

# %%
assays = ['NR-AR', 'NR-AR-LBD','NR-AhR', 'NR-Aromatase', 'NR-ER', 'NR-ER-LBD', 'NR-PPAR-gamma',
         'SR-ARE', 'SR-ATAD5', 'SR-HSE', 'SR-MMP', 'SR-p53']

# %%
fig, ax = plt.subplots(figsize=(10,8))

PrecisionRecallPlot(m2_precision_score, m2_recall_score, assays)

plt.title('ConvMol GraphConv Model 2 - Precision-Recall Curve for 12 assays') 
plt.legend(loc='upper right')
# plt.savefig('ConvMol M2 P-R.png')

# %%
fig, ax = plt.subplots(figsize=(10,8))

PrecisionRecallPlot(m4_precision_score, m4_recall_score, assays)

plt.title('ConvMol GraphConv Model 4 - Precision-Recall Curve for 12 assays') 
plt.legend(loc='upper right')
# plt.savefig('ConvMol M4 P-R.png')

# %%
fig, ax = plt.subplots(figsize=(10,8))

PrecisionRecallPlot(m6_precision_score, m6_recall_score, assays)

plt.title('ConvMol GraphConv Model 6 - Precision-Recall Curve for 12 assays') 
plt.legend(loc='upper right')
# plt.savefig('ConvMol M6 P-R.png')

# %% [markdown]
# ### Balanced Accuracy Score

# %%
def balanced_accuracy(y_true, y_pred):
    balanced_acc = []
    for i in range(len(y_true)):
        b_acc = balanced_accuracy_score(y_true[i], y_pred[i])
        balanced_acc.append(b_acc)
    return balanced_acc

# %%
m2_balanced_acc = balanced_accuracy(y_true, m2_y_pred_new)
m4_balanced_acc = balanced_accuracy(y_true, m4_y_pred_new)
m6_balanced_acc = balanced_accuracy(y_true, m6_y_pred_new)

# %%
b_acc_means = [np.mean(m2_balanced_acc), np.mean(m4_balanced_acc), np.mean(m6_balanced_acc)]
b_acc_means
# Out:
# [0.3942283675931129, 0.3737316637227961, 0.3944961542504836]

# %%
b_acc_median = [np.median(m2_balanced_acc), np.median(m4_balanced_acc), np.median(m6_balanced_acc)]
b_acc_median
# Out:
# [0.4090199994808822, 0.37182175622542596, 0.3970277284966355]

# %%
#Grouped bar plot
fig,ax = plt.subplots(figsize=(22,10))

width = 0.2

x=np.arange(12)
plt.bar(x-0.2, m2_balanced_acc, width, label='Model 2', color='navy')
plt.bar(x, m4_balanced_acc, width, label='Model 4',color='gold')
plt.bar(x+0.2, m6_balanced_acc, width, label='Model 6', color='teal')
plt.title('ConvMol GraphConv Model - Balanced Accuracy Score of Tox21 Assays', fontsize=16)
plt.ylabel('Balanced Accuracy Score', fontsize=14)
plt.xlabel('Tox21 Assays', fontsize=14)
plt.bar_label(ax.containers[0], fmt='%.3f', fontsize=12)
plt.bar_label(ax.containers[1], fmt='%.3f', fontsize=12)
plt.bar_label(ax.containers[2], fmt='%.3f', fontsize=12)
plt.xticks(x, assays, fontsize=12)
plt.yticks(fontsize=12)
plt.legend()
# plt.savefig('ConvMol BA.png')

# %%
#Balanced Accuracy Score split into NR and SR panels
fig, ax = plt.subplots(2,1, figsize=(22,20))

ax1 = ax[0]
ax2 = ax[1]

width = 0.2

#NR Panel
x=np.arange(7)

ax1.bar(x-0.2, m2_balanced_acc[0:7], width, label='Model 2', color='navy')
ax1.bar(x, m4_balanced_acc[0:7], width, label='Model 4', color='gold')
ax1.bar(x+0.2, m6_balanced_acc[0:7], width, label='Model 6', color='teal')
ax1.set_title('ConvMol GraphConv Model - Balanced Accuracy Score of Tox21 NR Assays', fontsize=16)
ax1.set_ylabel('Balanced Accuracy Score', fontsize=14)
ax1.set_xlabel('Nuclear Receptor Panel', fontsize=14)
ax1.bar_label(ax1.containers[0], fmt='%.3f', fontsize=12)
ax1.bar_label(ax1.containers[1], fmt='%.3f', fontsize=12)
ax1.bar_label(ax1.containers[2], fmt='%.3f', fontsize=12)
ax1.set_xticks(x, assays[0:7], fontsize=12)
ax1.legend()


#SR Panel
x1=np.arange(5)

ax2.bar(x1-0.2, m2_balanced_acc[7:12], width, label='Model 2', color='navy')
ax2.bar(x1, m4_balanced_acc[7:12], width, label='Model 4', color='gold')
ax2.bar(x1+0.2, m6_balanced_acc[7:12], width, label='Model 6', color='teal')
ax2.set_title('ConvMol GraphConv Model - Balanced Accuracy Score of Tox21 SR Assays', fontsize=16)
ax2.set_ylabel('Balanced Accuracy Score', fontsize=14)
ax2.set_xlabel('Stress Response Panel', fontsize=14)
ax2.bar_label(ax2.containers[0], fmt='%.3f', fontsize=12)
ax2.bar_label(ax2.containers[1], fmt='%.3f', fontsize=12)
ax2.bar_label(ax2.containers[2], fmt='%.3f', fontsize=12)
ax2.set_xticks(x1, assays[7:12], fontsize=12)
ax2.legend()

# %% [markdown]
# ### F1-Score

# %%
def f1Score(y_true, y_pred):
    f1_Score = []
    for i in range(len(y_true)):
        f1 = f1_score(y_true[i], y_pred[i])
        f1_Score.append(f1)
    return f1_Score

# %%
m2_f1 = f1Score(y_true, m2_y_pred_new)
m4_f1 = f1Score(y_true, m4_y_pred_new)
m6_f1 = f1Score(y_true, m6_y_pred_new)

# %%
f1_means = [np.mean(m2_f1), np.mean(m4_f1), np.mean(m6_f1)]
f1_means
# Out:
# [0.09186839941539347, 0.07410640558342248, 0.05694259579540603]

# %%
#Grouped bar plot
fig,ax = plt.subplots(figsize=(23,10))

width = 0.2

x=np.arange(12)
plt.bar(x-0.2, m2_f1, width, label='Model 2', color='navy')
plt.bar(x, m4_f1, width, label='Model 4', color='gold')
plt.bar(x+0.2, m6_f1, width, label='Model 6', color='teal')

plt.title('ConvMol GraphConv Model - F1 Score of Tox21 Assays', fontsize=16)
plt.ylabel('F1 Score', fontsize=14)
plt.xlabel('Tox21 Assays', fontsize=14)

#Bar labels
plt.bar_label(ax.containers[0], fmt='%.3f', fontsize=12)
plt.bar_label(ax.containers[1], fmt='%.3f', fontsize=12)
plt.bar_label(ax.containers[2], fmt='%.3f', fontsize=12)

#Assay labels
plt.xticks(x, assays, fontsize=12)
plt.yticks(fontsize=12)
plt.legend()
# plt.savefig('ConvMol F1.png')

# %%
#F1 Score split into NR and SR panels
fig, ax = plt.subplots(2,1, figsize=(22,15))

ax1 = ax[0]
ax2 = ax[1]

width = 0.2

#NR Panel
x=np.arange(7)

ax1.bar(x-0.2, m2_f1[0:7], width, label='Model 2', color='navy')
ax1.bar(x, m4_f1[0:7], width, label='Model 4', color='gold')
ax1.bar(x+0.2, m6_f1[0:7], width, label='Model 6', color='teal')
ax1.set_title('ConvMol GraphConv Model - F1 Score of Tox21 NR Assays', fontsize=16)
ax1.set_ylabel('F1 Score', fontsize=14)
ax1.set_xlabel('Nuclear Receptor Panel', fontsize=14)
ax1.bar_label(ax1.containers[0], fmt='%.3f', fontsize=12)
ax1.bar_label(ax1.containers[1], fmt='%.3f', fontsize=12)
ax1.bar_label(ax1.containers[2], fmt='%.3f', fontsize=12)
ax1.set_xticks(x, assays[0:7], fontsize=12)
ax1.legend()


#SR Panel
x1=np.arange(5)

ax2.bar(x1-0.2, m2_f1[7:12], width, label='Model 2', color='navy')
ax2.bar(x1, m4_f1[7:12], width, label='Model 4', color='gold')
ax2.bar(x1+0.2, m6_f1[7:12], width, label='Model 6', color='teal')
ax2.set_title('ConvMol GraphConv Model - F1 Score of Tox21 SR Assays', fontsize=16)
ax2.set_ylabel('F1 Score', fontsize=14)
ax2.set_xlabel('Stress Response Panel', fontsize=14)
ax2.bar_label(ax2.containers[0], fmt='%.3f', fontsize=12)
ax2.bar_label(ax2.containers[1], fmt='%.3f', fontsize=12)
ax2.bar_label(ax2.containers[2], fmt='%.3f', fontsize=12)
ax2.set_xticks(x1, assays[7:12], fontsize=12)
ax2.legend()

# %% [markdown]
# ### ROC-AUC Score

# %%
# Area Under the Receiver Operating Characteristic(ROC) Curve
def roc_auc(y_true, y_pred):
    rocauc=[]
    for i in range(len(y_true)):
        auroc = roc_auc_score(y_true[i], y_pred[i])
        rocauc.append(auroc)
    return rocauc

# %%
m2_roc_auc = roc_auc(y_true, m2_y_pred_new)
m4_roc_auc = roc_auc(y_true, m4_y_pred_new)
m6_roc_auc = roc_auc(y_true, m6_y_pred_new)

# %%
roc_means = [np.mean(m2_roc_auc), np.mean(m4_roc_auc), np.mean(m6_roc_auc)]
roc_means
# Out:
# [0.3942283675931129, 0.3737316637227961, 0.3944961542504836]

# %%
roc_median = [np.median(m2_roc_auc), np.median(m4_roc_auc), np.median(m6_roc_auc)]
roc_median
# Out:
# [0.4090199994808822, 0.3718217562254259, 0.3970277284966355]

# %%
#Grouped bar plot
fig,ax = plt.subplots(figsize=(22,10))
width = 0.2

x=np.arange(12)
plt.bar(x-0.2, m2_roc_auc, width, label='Model 2',color='navy')
plt.bar(x, m4_roc_auc, width, label='Model 4',color='gold')
plt.bar(x+0.2, m6_roc_auc, width, label='Model 6',color='teal')

plt.title('ConvMol GraphConv Model - ROC-AUC of Tox21 Assays', fontsize=16)
plt.ylabel('ROC-AUC', fontsize=14)
plt.xlabel('Tox21 Assays', fontsize=14)
plt.bar_label(ax.containers[0], fmt='%.3f', fontsize=12)
plt.bar_label(ax.containers[1], fmt='%.3f', fontsize=12)
plt.bar_label(ax.containers[2], fmt='%.3f', fontsize=12)
plt.xticks(x, assays, fontsize=12)
plt.yticks(fontsize=12)
plt.legend()
# plt.savefig('ConvMol ROC-AUC.png')

# %%
#ROC-AUC Score split into NR and SR panels
fig, ax = plt.subplots(2,1, figsize=(22,20))

ax1 = ax[0]
ax2 = ax[1]

width = 0.2

#NR Panel
x=np.arange(7)

ax1.bar(x-0.2, m2_roc_auc[0:7], width, label='Model 2', color='navy')
ax1.bar(x, m4_roc_auc[0:7], width, label='Model 4', color='gold')
ax1.bar(x+0.2, m6_roc_auc[0:7], width, label='Model 6', color='teal')
ax1.set_title('ConvMol GraphConv Model - ROC-AUC of Tox21 NR Assays', fontsize=16)
ax1.set_ylabel('ROC-AUC', fontsize=14)
ax1.set_xlabel('Nuclear Receptor Panel', fontsize=14)
ax1.bar_label(ax1.containers[0], fmt='%.3f', fontsize=12)
ax1.bar_label(ax1.containers[1], fmt='%.3f', fontsize=12)
ax1.bar_label(ax1.containers[2], fmt='%.3f', fontsize=12)
ax1.set_xticks(x, assays[0:7], fontsize=12)
ax1.legend()


#SR Panel
x1=np.arange(5)

ax2.bar(x1-0.2, m2_roc_auc[7:12], width, label='Model 2', color='navy')
ax2.bar(x1, m4_roc_auc[7:12], width, label='Model 4', color='gold')
ax2.bar(x1+0.2, m6_roc_auc[7:12], width, label='Model 6', color='teal')
ax2.set_title('ConvMol GraphConv Model - ROC-AUC of Tox21 SR Assays', fontsize=16)
ax2.set_ylabel('ROC-AUC', fontsize=14)
ax2.set_xlabel('Stress Response Panel', fontsize=14)
ax2.bar_label(ax2.containers[0], fmt='%.3f', fontsize=12)
ax2.bar_label(ax2.containers[1], fmt='%.3f', fontsize=12)
ax2.bar_label(ax2.containers[2], fmt='%.3f', fontsize=12)
ax2.set_xticks(x1, assays[7:12], fontsize=12)
ax2.legend()

# %% [markdown]
# Results of ROC-AUC score observed to be identical to balanced accuracy scores.
